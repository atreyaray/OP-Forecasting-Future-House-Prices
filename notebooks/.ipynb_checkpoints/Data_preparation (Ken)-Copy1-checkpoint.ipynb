# %%
import numpy as np
import pandas as pd
from matplotlib import pyplot as plt

df = pd.read_csv("../data/quarterly_data.csv", encoding = 'unicode_escape')

# %%
df1 = df.replace("..", np.nan)

# %%
df1
# Out:
#                                              Postal code  \
# 0      00100 Helsinki Keskusta - Etu-Töölö   (Helsinki )
# 1      00100 Helsinki Keskusta - Etu-Töölö   (Helsinki )
# 2      00100 Helsinki Keskusta - Etu-Töölö   (Helsinki )
# 3      00100 Helsinki Keskusta - Etu-Töölö   (Helsinki )
# 4      00100 Helsinki Keskusta - Etu-Töölö   (Helsinki )
# ...                                                  ...
# 10069                  99980 Utsjoki Keskus   (Utsjoki )
# 10070                  99980 Utsjoki Keskus   (Utsjoki )
# 10071                  99980 Utsjoki Keskus   (Utsjoki )
# 10072                  99980 Utsjoki Keskus   (Utsjoki )
# 10073                  99980 Utsjoki Keskus   (Utsjoki )
#
#                            Building type  \
# 0         Blocks of flats, one-room flat
# 1         Blocks of flats, two-room flat
# 2      Blocks of flats, three-room flat+
# 3                  Blocks of flats total
# 4                  Terraced houses total
# ...                                  ...
# 10069     Blocks of flats, two-room flat
# 10070  Blocks of flats, three-room flat+
# 10071              Blocks of flats total
# 10072              Terraced houses total
# 10073               Building types total
#
#       2010Q1 Price per square meter (EUR/m2)  \
# 0                                       5458
# 1                                       5164
# 2                                       4944
# 3                                       5168
# 4                                        NaN
# ...                                      ...
# 10069                                    NaN
# 10070                                    NaN
# 10071                                    NaN
# 10072                                    NaN
# 10073                                    NaN
#
#       2010Q2 Price per square meter (EUR/m2)  \
# 0                                       5347
# 1                                       5021
# 2                                       5396
# 3                                       5219
# 4                                        NaN
# ...                                      ...
# 10069                                    NaN
# 10070                                    NaN
# 10071                                    NaN
# 10072                                    NaN
# 10073                                    NaN
#
#       2010Q3 Price per square meter (EUR/m2)  \
# 0                                       5826
# 1                                       5081
# 2                                       4828
# 3                                       5181
# 4                                        NaN
# ...                                      ...
# 10069                                    NaN
# 10070                                    NaN
# 10071                                    NaN
# 10072                                    NaN
# 10073                                    NaN
#
#       2010Q4 Price per square meter (EUR/m2)  \
# 0                                       5566
# 1                                       5006
# 2                                       5394
# 3                                       5269
# 4                                        NaN
# ...                                      ...
# 10069                                    NaN
# 10070                                    NaN
# 10071                                    NaN
# 10072                                    NaN
# 10073                                    NaN
#
#       2011Q1 Price per square meter (EUR/m2)  \
# 0                                       5545
# 1                                       5713
# 2                                       5571
# 3                                       5632
# 4                                        NaN
# ...                                      ...
# 10069                                    NaN
# 10070                                    NaN
# 10071                                    NaN
# 10072                                    NaN
# 10073                                    NaN
#
#       2011Q2 Price per square meter (EUR/m2)  \
# 0                                       5812
# 1                                       5866
# 2                                       5709
# 3                                       5807
# 4                                        NaN
# ...                                      ...
# 10069                                    NaN
# 10070                                    NaN
# 10071                                    NaN
# 10072                                    NaN
# 10073                                    NaN
#
#       2011Q3 Price per square meter (EUR/m2)  \
# 0                                       5909
# 1                                       5552
# 2                                       5450
# 3                                       5630
# 4                                        NaN
# ...                                      ...
# 10069                                    NaN
# 10070                                    NaN
# 10071                                    NaN
# 10072                                    NaN
# 10073                                    NaN
#
#       2011Q4 Price per square meter (EUR/m2)  ...  \
# 0                                       5856  ...
# 1                                       5614  ...
# 2                                       5010  ...
# 3                                       5511  ...
# 4                                        NaN  ...
# ...                                      ...  ...
# 10069                                    NaN  ...
# 10070                                    NaN  ...
# 10071                                    NaN  ...
# 10072                                    NaN  ...
# 10073                                    NaN  ...
#
#       2019Q1 Price per square meter (EUR/m2)  \
# 0                                       7755
# 1                                       6914
# 2                                       6883
# 3                                       7043
# 4                                        NaN
# ...                                      ...
# 10069                                    NaN
# 10070                                    NaN
# 10071                                    NaN
# 10072                                    NaN
# 10073                                    NaN
#
#       2019Q2 Price per square meter (EUR/m2)  \
# 0                                       8332
# 1                                       7694
# 2                                       6846
# 3                                       7478
# 4                                        NaN
# ...                                      ...
# 10069                                    NaN
# 10070                                    NaN
# 10071                                    NaN
# 10072                                    NaN
# 10073                                    NaN
#
#       2019Q3 Price per square meter (EUR/m2)  \
# 0                                       8130
# 1                                       6901
# 2                                       7379
# 3                                       7476
# 4                                        NaN
# ...                                      ...
# 10069                                    NaN
# 10070                                    NaN
# 10071                                    NaN
# 10072                                    NaN
# 10073                                    NaN
#
#       2019Q4 Price per square meter (EUR/m2)  \
# 0                                       8068
# 1                                       7435
# 2                                       6728
# 3                                       7345
# 4                                        NaN
# ...                                      ...
# 10069                                    NaN
# 10070                                    NaN
# 10071                                    NaN
# 10072                                    NaN
# 10073                                    NaN
#
#       2020Q1 Price per square meter (EUR/m2)  \
# 0                                       7802
# 1                                       7573
# 2                                       7205
# 3                                       7460
# 4                                        NaN
# ...                                      ...
# 10069                                    NaN
# 10070                                    NaN
# 10071                                    NaN
# 10072                                    NaN
# 10073                                    NaN
#
#       2020Q2 Price per square meter (EUR/m2)  \
# 0                                       8543
# 1                                       7398
# 2                                       6678
# 3                                       7275
# 4                                        NaN
# ...                                      ...
# 10069                                    NaN
# 10070                                    NaN
# 10071                                    NaN
# 10072                                    NaN
# 10073                                    NaN
#
#       2020Q3 Price per square meter (EUR/m2)  \
# 0                                       9170
# 1                                       7868
# 2                                       7178
# 3                                       8058
# 4                                        NaN
# ...                                      ...
# 10069                                    NaN
# 10070                                    NaN
# 10071                                    NaN
# 10072                                    NaN
# 10073                                    NaN
#
#       2020Q4 Price per square meter (EUR/m2)  \
# 0                                       7517
# 1                                       7700
# 2                                       7405
# 3                                       7540
# 4                                        NaN
# ...                                      ...
# 10069                                    NaN
# 10070                                    NaN
# 10071                                    NaN
# 10072                                    NaN
# 10073                                    NaN
#
#       2021Q1* Price per square meter (EUR/m2)  \
# 0                                        8872
# 1                                        7829
# 2                                        8053
# 3                                        8188
# 4                                         NaN
# ...                                       ...
# 10069                                     NaN
# 10070                                     NaN
# 10071                                     NaN
# 10072                                     NaN
# 10073                                     NaN
#
#       2021Q2* Price per square meter (EUR/m2)
# 0                                        8596
# 1                                        7974
# 2                                        8174
# 3                                        8188
# 4                                         NaN
# ...                                       ...
# 10069                                     NaN
# 10070                                     NaN
# 10071                                     NaN
# 10072                                     NaN
# 10073                                     NaN
#
# [10074 rows x 48 columns]

# %%
# original source https://machinelearningmastery.com/iterative-imputation-for-missing-values-in-machine-learning/
# summarize the number of rows with missing values for each column
for i in range(df1.shape[1]):
    n_miss = df1.iloc[:,i].isnull().sum()
    perc = n_miss / df1.shape[0] * 100
    print('> %d, Missing: %d (%.1f%%)' % (i, n_miss, perc))
# Out:
# > 0, Missing: 0 (0.0%)
# > 1, Missing: 0 (0.0%)
# > 2, Missing: 8466 (84.0%)
# > 3, Missing: 8371 (83.1%)
# > 4, Missing: 8437 (83.8%)
# > 5, Missing: 8470 (84.1%)
# > 6, Missing: 8429 (83.7%)
# > 7, Missing: 8383 (83.2%)
# > 8, Missing: 8401 (83.4%)
# > 9, Missing: 8676 (86.1%)
# > 10, Missing: 8517 (84.5%)
# > 11, Missing: 8388 (83.3%)
# > 12, Missing: 7979 (79.2%)
# > 13, Missing: 8071 (80.1%)
# > 14, Missing: 8538 (84.8%)
# > 15, Missing: 8544 (84.8%)
# > 16, Missing: 8596 (85.3%)
# > 17, Missing: 8736 (86.7%)
# > 18, Missing: 8683 (86.2%)
# > 19, Missing: 8637 (85.7%)
# > 20, Missing: 8653 (85.9%)
# > 21, Missing: 8760 (87.0%)
# > 22, Missing: 8687 (86.2%)
# > 23, Missing: 8612 (85.5%)
# > 24, Missing: 8579 (85.2%)
# > 25, Missing: 8677 (86.1%)
# > 26, Missing: 8747 (86.8%)
# > 27, Missing: 8551 (84.9%)
# > 28, Missing: 8647 (85.8%)
# > 29, Missing: 8769 (87.0%)
# > 30, Missing: 8640 (85.8%)
# > 31, Missing: 8682 (86.2%)
# > 32, Missing: 8575 (85.1%)
# > 33, Missing: 8739 (86.7%)
# > 34, Missing: 8721 (86.6%)
# > 35, Missing: 8655 (85.9%)
# > 36, Missing: 8711 (86.5%)
# > 37, Missing: 8721 (86.6%)
# > 38, Missing: 8794 (87.3%)
# > 39, Missing: 8719 (86.5%)
# > 40, Missing: 8662 (86.0%)
# > 41, Missing: 8732 (86.7%)
# > 42, Missing: 8694 (86.3%)
# > 43, Missing: 8816 (87.5%)
# > 44, Missing: 8533 (84.7%)
# > 45, Missing: 8477 (84.1%)
# > 46, Missing: 8496 (84.3%)
# > 47, Missing: 8655 (85.9%)

# %%
## Categories and numerical features to different dfs

cat = df1.iloc[:,0:2]
num = df1.iloc[:,2:]
num_columns = num.columns

# %%
from sklearn.experimental import enable_iterative_imputer
from sklearn.impute import IterativeImputer

imp = IterativeImputer(max_iter=10, random_state=0)
num_imp = imp.fit_transform(num)
# Out:
# /Users/kenriippa/anaconda3/lib/python3.8/site-packages/sklearn/impute/_iterative.py:685: ConvergenceWarning: [IterativeImputer] Early stopping criterion not reached.
#   warnings.warn("[IterativeImputer] Early stopping criterion not"

# %%
df_num_imp = pd.DataFrame(num_imp, columns=num_columns)
df_num_imp
# Out:
#        2010Q1 Price per square meter (EUR/m2)  \
# 0                                 5458.000000
# 1                                 5164.000000
# 2                                 4944.000000
# 3                                 5168.000000
# 4                                 1783.222523
# ...                                       ...
# 10069                             1783.222523
# 10070                             1783.222523
# 10071                             1783.222523
# 10072                             1783.222523
# 10073                             1783.222523
#
#        2010Q2 Price per square meter (EUR/m2)  \
# 0                                 5347.000000
# 1                                 5021.000000
# 2                                 5396.000000
# 3                                 5219.000000
# 4                                 1824.975495
# ...                                       ...
# 10069                             1824.975495
# 10070                             1824.975495
# 10071                             1824.975495
# 10072                             1824.975495
# 10073                             1824.975495
#
#        2010Q3 Price per square meter (EUR/m2)  \
# 0                                 5826.000000
# 1                                 5081.000000
# 2                                 4828.000000
# 3                                 5181.000000
# 4                                 1837.301766
# ...                                       ...
# 10069                             1837.301766
# 10070                             1837.301766
# 10071                             1837.301766
# 10072                             1837.301766
# 10073                             1837.301766
#
#        2010Q4 Price per square meter (EUR/m2)  \
# 0                                 5566.000000
# 1                                 5006.000000
# 2                                 5394.000000
# 3                                 5269.000000
# 4                                 1822.620585
# ...                                       ...
# 10069                             1822.620585
# 10070                             1822.620585
# 10071                             1822.620585
# 10072                             1822.620585
# 10073                             1822.620585
#
#        2011Q1 Price per square meter (EUR/m2)  \
# 0                                 5545.000000
# 1                                 5713.000000
# 2                                 5571.000000
# 3                                 5632.000000
# 4                                 1869.018392
# ...                                       ...
# 10069                             1869.018392
# 10070                             1869.018392
# 10071                             1869.018392
# 10072                             1869.018392
# 10073                             1869.018392
#
#        2011Q2 Price per square meter (EUR/m2)  \
# 0                                 5812.000000
# 1                                 5866.000000
# 2                                 5709.000000
# 3                                 5807.000000
# 4                                 1898.716837
# ...                                       ...
# 10069                             1898.716837
# 10070                             1898.716837
# 10071                             1898.716837
# 10072                             1898.716837
# 10073                             1898.716837
#
#        2011Q3 Price per square meter (EUR/m2)  \
# 0                                 5909.000000
# 1                                 5552.000000
# 2                                 5450.000000
# 3                                 5630.000000
# 4                                 1894.228569
# ...                                       ...
# 10069                             1894.228569
# 10070                             1894.228569
# 10071                             1894.228569
# 10072                             1894.228569
# 10073                             1894.228569
#
#        2011Q4 Price per square meter (EUR/m2)  \
# 0                                 5856.000000
# 1                                 5614.000000
# 2                                 5010.000000
# 3                                 5511.000000
# 4                                 1862.702913
# ...                                       ...
# 10069                             1862.702913
# 10070                             1862.702913
# 10071                             1862.702913
# 10072                             1862.702913
# 10073                             1862.702913
#
#        2012Q1 Price per square meter (EUR/m2)  \
# 0                                 5785.000000
# 1                                 6020.000000
# 2                                 5704.000000
# 3                                 5843.000000
# 4                                 1900.623898
# ...                                       ...
# 10069                             1900.623898
# 10070                             1900.623898
# 10071                             1900.623898
# 10072                             1900.623898
# 10073                             1900.623898
#
#        2012Q2 Price per square meter (EUR/m2)  ...  \
# 0                                 6436.000000  ...
# 1                                 5814.000000  ...
# 2                                 5466.000000  ...
# 3                                 5899.000000  ...
# 4                                 1930.519312  ...
# ...                                       ...  ...
# 10069                             1930.519312  ...
# 10070                             1930.519312  ...
# 10071                             1930.519312  ...
# 10072                             1930.519312  ...
# 10073                             1930.519312  ...
#
#        2019Q1 Price per square meter (EUR/m2)  \
# 0                                 7755.000000
# 1                                 6914.000000
# 2                                 6883.000000
# 3                                 7043.000000
# 4                                 2084.801645
# ...                                       ...
# 10069                             2084.801645
# 10070                             2084.801645
# 10071                             2084.801645
# 10072                             2084.801645
# 10073                             2084.801645
#
#        2019Q2 Price per square meter (EUR/m2)  \
# 0                                 8332.000000
# 1                                 7694.000000
# 2                                 6846.000000
# 3                                 7478.000000
# 4                                 2117.757075
# ...                                       ...
# 10069                             2117.757075
# 10070                             2117.757075
# 10071                             2117.757075
# 10072                             2117.757075
# 10073                             2117.757075
#
#        2019Q3 Price per square meter (EUR/m2)  \
# 0                                 8130.000000
# 1                                 6901.000000
# 2                                 7379.000000
# 3                                 7476.000000
# 4                                 2101.019245
# ...                                       ...
# 10069                             2101.019245
# 10070                             2101.019245
# 10071                             2101.019245
# 10072                             2101.019245
# 10073                             2101.019245
#
#        2019Q4 Price per square meter (EUR/m2)  \
# 0                                   8068.0000
# 1                                   7435.0000
# 2                                   6728.0000
# 3                                   7345.0000
# 4                                   2069.1361
# ...                                       ...
# 10069                               2069.1361
# 10070                               2069.1361
# 10071                               2069.1361
# 10072                               2069.1361
# 10073                               2069.1361
#
#        2020Q1 Price per square meter (EUR/m2)  \
# 0                                 7802.000000
# 1                                 7573.000000
# 2                                 7205.000000
# 3                                 7460.000000
# 4                                 2135.629373
# ...                                       ...
# 10069                             2135.629373
# 10070                             2135.629373
# 10071                             2135.629373
# 10072                             2135.629373
# 10073                             2135.629373
#
#        2020Q2 Price per square meter (EUR/m2)  \
# 0                                 8543.000000
# 1                                 7398.000000
# 2                                 6678.000000
# 3                                 7275.000000
# 4                                 2152.308609
# ...                                       ...
# 10069                             2152.308609
# 10070                             2152.308609
# 10071                             2152.308609
# 10072                             2152.308609
# 10073                             2152.308609
#
#        2020Q3 Price per square meter (EUR/m2)  \
# 0                                 9170.000000
# 1                                 7868.000000
# 2                                 7178.000000
# 3                                 8058.000000
# 4                                 2173.893109
# ...                                       ...
# 10069                             2173.893109
# 10070                             2173.893109
# 10071                             2173.893109
# 10072                             2173.893109
# 10073                             2173.893109
#
#        2020Q4 Price per square meter (EUR/m2)  \
# 0                                 7517.000000
# 1                                 7700.000000
# 2                                 7405.000000
# 3                                 7540.000000
# 4                                 2172.261334
# ...                                       ...
# 10069                             2172.261334
# 10070                             2172.261334
# 10071                             2172.261334
# 10072                             2172.261334
# 10073                             2172.261334
#
#        2021Q1* Price per square meter (EUR/m2)  \
# 0                                  8872.000000
# 1                                  7829.000000
# 2                                  8053.000000
# 3                                  8188.000000
# 4                                  2219.056507
# ...                                        ...
# 10069                              2219.056507
# 10070                              2219.056507
# 10071                              2219.056507
# 10072                              2219.056507
# 10073                              2219.056507
#
#        2021Q2* Price per square meter (EUR/m2)
# 0                                  8596.000000
# 1                                  7974.000000
# 2                                  8174.000000
# 3                                  8188.000000
# 4                                  2290.004173
# ...                                        ...
# 10069                              2290.004173
# 10070                              2290.004173
# 10071                              2290.004173
# 10072                              2290.004173
# 10073                              2290.004173
#
# [10074 rows x 46 columns]

# %%
df_num_imp.isnull().sum()
# Out:
# 2010Q1 Price per square meter (EUR/m2)     0
# 2010Q2 Price per square meter (EUR/m2)     0
# 2010Q3 Price per square meter (EUR/m2)     0
# 2010Q4 Price per square meter (EUR/m2)     0
# 2011Q1 Price per square meter (EUR/m2)     0
# 2011Q2 Price per square meter (EUR/m2)     0
# 2011Q3 Price per square meter (EUR/m2)     0
# 2011Q4 Price per square meter (EUR/m2)     0
# 2012Q1 Price per square meter (EUR/m2)     0
# 2012Q2 Price per square meter (EUR/m2)     0
# 2012Q3 Price per square meter (EUR/m2)     0
# 2012Q4 Price per square meter (EUR/m2)     0
# 2013Q1 Price per square meter (EUR/m2)     0
# 2013Q2 Price per square meter (EUR/m2)     0
# 2013Q3 Price per square meter (EUR/m2)     0
# 2013Q4 Price per square meter (EUR/m2)     0
# 2014Q1 Price per square meter (EUR/m2)     0
# 2014Q2 Price per square meter (EUR/m2)     0
# 2014Q3 Price per square meter (EUR/m2)     0
# 2014Q4 Price per square meter (EUR/m2)     0
# 2015Q1 Price per square meter (EUR/m2)     0
# 2015Q2 Price per square meter (EUR/m2)     0
# 2015Q3 Price per square meter (EUR/m2)     0
# 2015Q4 Price per square meter (EUR/m2)     0
# 2016Q1 Price per square meter (EUR/m2)     0
# 2016Q2 Price per square meter (EUR/m2)     0
# 2016Q3 Price per square meter (EUR/m2)     0
# 2016Q4 Price per square meter (EUR/m2)     0
# 2017Q1 Price per square meter (EUR/m2)     0
# 2017Q2 Price per square meter (EUR/m2)     0
# 2017Q3 Price per square meter (EUR/m2)     0
# 2017Q4 Price per square meter (EUR/m2)     0
# 2018Q1 Price per square meter (EUR/m2)     0
# 2018Q2 Price per square meter (EUR/m2)     0
# 2018Q3 Price per square meter (EUR/m2)     0
# 2018Q4 Price per square meter (EUR/m2)     0
# 2019Q1 Price per square meter (EUR/m2)     0
# 2019Q2 Price per square meter (EUR/m2)     0
# 2019Q3 Price per square meter (EUR/m2)     0
# 2019Q4 Price per square meter (EUR/m2)     0
# 2020Q1 Price per square meter (EUR/m2)     0
# 2020Q2 Price per square meter (EUR/m2)     0
# 2020Q3 Price per square meter (EUR/m2)     0
# 2020Q4 Price per square meter (EUR/m2)     0
# 2021Q1* Price per square meter (EUR/m2)    0
# 2021Q2* Price per square meter (EUR/m2)    0
# dtype: int64

# %%
df_imp = pd.concat([cat, df_num_imp],axis=1)

# %%
df_imp.head()
# Out:
#                                          Postal code  \
# 0  00100 Helsinki Keskusta - Etu-Töölö   (Helsinki )
# 1  00100 Helsinki Keskusta - Etu-Töölö   (Helsinki )
# 2  00100 Helsinki Keskusta - Etu-Töölö   (Helsinki )
# 3  00100 Helsinki Keskusta - Etu-Töölö   (Helsinki )
# 4  00100 Helsinki Keskusta - Etu-Töölö   (Helsinki )
#
#                        Building type  2010Q1 Price per square meter (EUR/m2)  \
# 0     Blocks of flats, one-room flat                             5458.000000
# 1     Blocks of flats, two-room flat                             5164.000000
# 2  Blocks of flats, three-room flat+                             4944.000000
# 3              Blocks of flats total                             5168.000000
# 4              Terraced houses total                             1783.222523
#
#    2010Q2 Price per square meter (EUR/m2)  \
# 0                             5347.000000
# 1                             5021.000000
# 2                             5396.000000
# 3                             5219.000000
# 4                             1824.975495
#
#    2010Q3 Price per square meter (EUR/m2)  \
# 0                             5826.000000
# 1                             5081.000000
# 2                             4828.000000
# 3                             5181.000000
# 4                             1837.301766
#
#    2010Q4 Price per square meter (EUR/m2)  \
# 0                             5566.000000
# 1                             5006.000000
# 2                             5394.000000
# 3                             5269.000000
# 4                             1822.620585
#
#    2011Q1 Price per square meter (EUR/m2)  \
# 0                             5545.000000
# 1                             5713.000000
# 2                             5571.000000
# 3                             5632.000000
# 4                             1869.018392
#
#    2011Q2 Price per square meter (EUR/m2)  \
# 0                             5812.000000
# 1                             5866.000000
# 2                             5709.000000
# 3                             5807.000000
# 4                             1898.716837
#
#    2011Q3 Price per square meter (EUR/m2)  \
# 0                             5909.000000
# 1                             5552.000000
# 2                             5450.000000
# 3                             5630.000000
# 4                             1894.228569
#
#    2011Q4 Price per square meter (EUR/m2)  ...  \
# 0                             5856.000000  ...
# 1                             5614.000000  ...
# 2                             5010.000000  ...
# 3                             5511.000000  ...
# 4                             1862.702913  ...
#
#    2019Q1 Price per square meter (EUR/m2)  \
# 0                             7755.000000
# 1                             6914.000000
# 2                             6883.000000
# 3                             7043.000000
# 4                             2084.801645
#
#    2019Q2 Price per square meter (EUR/m2)  \
# 0                             8332.000000
# 1                             7694.000000
# 2                             6846.000000
# 3                             7478.000000
# 4                             2117.757075
#
#    2019Q3 Price per square meter (EUR/m2)  \
# 0                             8130.000000
# 1                             6901.000000
# 2                             7379.000000
# 3                             7476.000000
# 4                             2101.019245
#
#    2019Q4 Price per square meter (EUR/m2)  \
# 0                               8068.0000
# 1                               7435.0000
# 2                               6728.0000
# 3                               7345.0000
# 4                               2069.1361
#
#    2020Q1 Price per square meter (EUR/m2)  \
# 0                             7802.000000
# 1                             7573.000000
# 2                             7205.000000
# 3                             7460.000000
# 4                             2135.629373
#
#    2020Q2 Price per square meter (EUR/m2)  \
# 0                             8543.000000
# 1                             7398.000000
# 2                             6678.000000
# 3                             7275.000000
# 4                             2152.308609
#
#    2020Q3 Price per square meter (EUR/m2)  \
# 0                             9170.000000
# 1                             7868.000000
# 2                             7178.000000
# 3                             8058.000000
# 4                             2173.893109
#
#    2020Q4 Price per square meter (EUR/m2)  \
# 0                             7517.000000
# 1                             7700.000000
# 2                             7405.000000
# 3                             7540.000000
# 4                             2172.261334
#
#    2021Q1* Price per square meter (EUR/m2)  \
# 0                              8872.000000
# 1                              7829.000000
# 2                              8053.000000
# 3                              8188.000000
# 4                              2219.056507
#
#    2021Q2* Price per square meter (EUR/m2)
# 0                              8596.000000
# 1                              7974.000000
# 2                              8174.000000
# 3                              8188.000000
# 4                              2290.004173
#
# [5 rows x 48 columns]

# %%
df4 = df_imp.melt(id_vars=["Postal code", "Building type"],var_name="Quarter", value_name="EUR/m2")

# %%
df4.loc[df4["Postal code"] == "00100 Helsinki Keskusta - Etu-Töölö   (Helsinki )"]
# Out:
#                                               Postal code  \
# 0       00100 Helsinki Keskusta - Etu-Töölö   (Helsinki )
# 1       00100 Helsinki Keskusta - Etu-Töölö   (Helsinki )
# 2       00100 Helsinki Keskusta - Etu-Töölö   (Helsinki )
# 3       00100 Helsinki Keskusta - Etu-Töölö   (Helsinki )
# 4       00100 Helsinki Keskusta - Etu-Töölö   (Helsinki )
# ...                                                   ...
# 453331  00100 Helsinki Keskusta - Etu-Töölö   (Helsinki )
# 453332  00100 Helsinki Keskusta - Etu-Töölö   (Helsinki )
# 453333  00100 Helsinki Keskusta - Etu-Töölö   (Helsinki )
# 453334  00100 Helsinki Keskusta - Etu-Töölö   (Helsinki )
# 453335  00100 Helsinki Keskusta - Etu-Töölö   (Helsinki )
#
#                             Building type  \
# 0          Blocks of flats, one-room flat
# 1          Blocks of flats, two-room flat
# 2       Blocks of flats, three-room flat+
# 3                   Blocks of flats total
# 4                   Terraced houses total
# ...                                   ...
# 453331     Blocks of flats, two-room flat
# 453332  Blocks of flats, three-room flat+
# 453333              Blocks of flats total
# 453334              Terraced houses total
# 453335               Building types total
#
#                                         Quarter       EUR/m2
# 0        2010Q1 Price per square meter (EUR/m2)  5458.000000
# 1        2010Q1 Price per square meter (EUR/m2)  5164.000000
# 2        2010Q1 Price per square meter (EUR/m2)  4944.000000
# 3        2010Q1 Price per square meter (EUR/m2)  5168.000000
# 4        2010Q1 Price per square meter (EUR/m2)  1783.222523
# ...                                         ...          ...
# 453331  2021Q2* Price per square meter (EUR/m2)  7974.000000
# 453332  2021Q2* Price per square meter (EUR/m2)  8174.000000
# 453333  2021Q2* Price per square meter (EUR/m2)  8188.000000
# 453334  2021Q2* Price per square meter (EUR/m2)  2290.004173
# 453335  2021Q2* Price per square meter (EUR/m2)  8188.000000
#
# [276 rows x 4 columns]

# %%
### Regex to change quarters to datetime
import datetime as date

def quarter_to_datetime(row):
    dates = {"Q1": "1/1", "Q2":"4/1", "Q3":"7/1", "Q4":"10/1"}
    string = row.replace("*", "").split(" ")[0]
    year, quarter = string[:4], string[4:]
    datetime_str = dates[quarter] + "/" + year
    return date.datetime.strptime(datetime_str, '%d/%m/%Y')
    
    
df4["Quarter"] = df4["Quarter"].apply(lambda row: quarter_to_datetime(row))
df4
# Out:
#                                               Postal code  \
# 0       00100 Helsinki Keskusta - Etu-Töölö   (Helsinki )
# 1       00100 Helsinki Keskusta - Etu-Töölö   (Helsinki )
# 2       00100 Helsinki Keskusta - Etu-Töölö   (Helsinki )
# 3       00100 Helsinki Keskusta - Etu-Töölö   (Helsinki )
# 4       00100 Helsinki Keskusta - Etu-Töölö   (Helsinki )
# ...                                                   ...
# 463399                  99980 Utsjoki Keskus   (Utsjoki )
# 463400                  99980 Utsjoki Keskus   (Utsjoki )
# 463401                  99980 Utsjoki Keskus   (Utsjoki )
# 463402                  99980 Utsjoki Keskus   (Utsjoki )
# 463403                  99980 Utsjoki Keskus   (Utsjoki )
#
#                             Building type    Quarter       EUR/m2
# 0          Blocks of flats, one-room flat 2010-01-01  5458.000000
# 1          Blocks of flats, two-room flat 2010-01-01  5164.000000
# 2       Blocks of flats, three-room flat+ 2010-01-01  4944.000000
# 3                   Blocks of flats total 2010-01-01  5168.000000
# 4                   Terraced houses total 2010-01-01  1783.222523
# ...                                   ...        ...          ...
# 463399     Blocks of flats, two-room flat 2021-01-04  2290.004173
# 463400  Blocks of flats, three-room flat+ 2021-01-04  2290.004173
# 463401              Blocks of flats total 2021-01-04  2290.004173
# 463402              Terraced houses total 2021-01-04  2290.004173
# 463403               Building types total 2021-01-04  2290.004173
#
# [463404 rows x 4 columns]

# %%
### Split postal code and place

df4[['Postal code', 'Location']] = df4['Postal code'].str.split(' ', 1, expand=True)
df4
# Out:
#        Postal code                      Building type    Quarter       EUR/m2  \
# 0            00100     Blocks of flats, one-room flat 2010-01-01  5458.000000
# 1            00100     Blocks of flats, two-room flat 2010-01-01  5164.000000
# 2            00100  Blocks of flats, three-room flat+ 2010-01-01  4944.000000
# 3            00100              Blocks of flats total 2010-01-01  5168.000000
# 4            00100              Terraced houses total 2010-01-01  1783.222523
# ...            ...                                ...        ...          ...
# 463399       99980     Blocks of flats, two-room flat 2021-01-04  2290.004173
# 463400       99980  Blocks of flats, three-room flat+ 2021-01-04  2290.004173
# 463401       99980              Blocks of flats total 2021-01-04  2290.004173
# 463402       99980              Terraced houses total 2021-01-04  2290.004173
# 463403       99980               Building types total 2021-01-04  2290.004173
#
#                                            Location
# 0       Helsinki Keskusta - Etu-Töölö   (Helsinki )
# 1       Helsinki Keskusta - Etu-Töölö   (Helsinki )
# 2       Helsinki Keskusta - Etu-Töölö   (Helsinki )
# 3       Helsinki Keskusta - Etu-Töölö   (Helsinki )
# 4       Helsinki Keskusta - Etu-Töölö   (Helsinki )
# ...                                             ...
# 463399                  Utsjoki Keskus   (Utsjoki )
# 463400                  Utsjoki Keskus   (Utsjoki )
# 463401                  Utsjoki Keskus   (Utsjoki )
# 463402                  Utsjoki Keskus   (Utsjoki )
# 463403                  Utsjoki Keskus   (Utsjoki )
#
# [463404 rows x 5 columns]

# %%
# !pip install pgeocode
# Out:
# Requirement already satisfied: pgeocode in /Users/kenriippa/Documents/School/OP-Forecasting-Future-House-Prices/venv/lib/python3.8/site-packages (0.3.0)
# Requirement already satisfied: numpy in /Users/kenriippa/Documents/School/OP-Forecasting-Future-House-Prices/venv/lib/python3.8/site-packages (from pgeocode) (1.21.2)
# Requirement already satisfied: requests in /Users/kenriippa/Documents/School/OP-Forecasting-Future-House-Prices/venv/lib/python3.8/site-packages (from pgeocode) (2.26.0)
# Requirement already satisfied: pandas in /Users/kenriippa/Documents/School/OP-Forecasting-Future-House-Prices/venv/lib/python3.8/site-packages (from pgeocode) (1.3.3)
# Requirement already satisfied: charset-normalizer~=2.0.0; python_version >= "3" in /Users/kenriippa/Documents/School/OP-Forecasting-Future-House-Prices/venv/lib/python3.8/site-packages (from requests->pgeocode) (2.0.6)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/kenriippa/Documents/School/OP-Forecasting-Future-House-Prices/venv/lib/python3.8/site-packages (from requests->pgeocode) (2021.5.30)
# Requirement already satisfied: idna<4,>=2.5; python_version >= "3" in /Users/kenriippa/Documents/School/OP-Forecasting-Future-House-Prices/venv/lib/python3.8/site-packages (from requests->pgeocode) (3.2)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /Users/kenriippa/Documents/School/OP-Forecasting-Future-House-Prices/venv/lib/python3.8/site-packages (from requests->pgeocode) (1.26.7)
# Requirement already satisfied: pytz>=2017.3 in /Users/kenriippa/Documents/School/OP-Forecasting-Future-House-Prices/venv/lib/python3.8/site-packages (from pandas->pgeocode) (2021.3)
# Requirement already satisfied: python-dateutil>=2.7.3 in /Users/kenriippa/Documents/School/OP-Forecasting-Future-House-Prices/venv/lib/python3.8/site-packages (from pandas->pgeocode) (2.8.2)
# Requirement already satisfied: six>=1.5 in /Users/kenriippa/Documents/School/OP-Forecasting-Future-House-Prices/venv/lib/python3.8/site-packages (from python-dateutil>=2.7.3->pandas->pgeocode) (1.16.0)
# WARNING: You are using pip version 20.2.3; however, version 21.2.4 is available.
# You should consider upgrading via the '/Users/kenriippa/Documents/School/OP-Forecasting-Future-House-Prices/venv/bin/python -m pip install --upgrade pip' command.

# %%
import pgeocode
import time

# %%
"""def postal_code_to_geolocation(row):
    nomi = pgeocode.Nominatim('fi')
    location = nomi.query_postal_code(postal_code)
    return location.latitude, location.longitude"""
# Out:
# "def postal_code_to_geolocation(row):\n    nomi = pgeocode.Nominatim('fi')\n    location = nomi.query_postal_code(postal_code)\n    return location.latitude, location.longitude"

# %%
"""geolocation_dic = {}

latitude, longitude = postal_code_to_geolocation()
print(latitude)
geolocation_dic[p] = (latitude, longitude)
time.sleep(10)"""
# Out:
# 'geolocation_dic = {}\n\nlatitude, longitude = postal_code_to_geolocation()\nprint(latitude)\ngeolocation_dic[p] = (latitude, longitude)\ntime.sleep(10)'

# %%
postal_code_list = list(df4["Postal code"].unique())
nomi = pgeocode.Nominatim('fi')
location = nomi.query_postal_code(postal_code_list)

# %%
location
# Out:
#      postal_code country_code                      place_name state_name  \
# 0          00100           FI  Helsinki                          Uusimaa
# 1          00120           FI  Helsinki                          Uusimaa
# 2          00130           FI  Helsinki                          Uusimaa
# 3          00140           FI  Helsinki                          Uusimaa
# 4          00150           FI  Helsinki                          Uusimaa
# ...          ...          ...                             ...        ...
# 1674       99830           FI                      Saariselkä    Lapland
# 1675       99870           FI                           Inari    Lapland
# 1676       99930           FI                    Sevettijärvi    Lapland
# 1677       99950           FI                    Karigasniemi    Lapland
# 1678       99980           FI                         Utsjoki    Lapland
#
#       state_code    county_name  county_code community_name  community_code  \
# 0            1.0       Helsinki         11.0       Helsinki            91.0
# 1            1.0       Helsinki         11.0       Helsinki            91.0
# 2            1.0       Helsinki         11.0       Helsinki            91.0
# 3            1.0       Helsinki         11.0       Helsinki            91.0
# 4            1.0       Helsinki         11.0       Helsinki            91.0
# ...          ...            ...          ...            ...             ...
# 1674        19.0  Pohjois-Lappi        197.0          Inari           148.0
# 1675        19.0  Pohjois-Lappi        197.0          Inari           148.0
# 1676        19.0  Pohjois-Lappi        197.0          Inari           148.0
# 1677        19.0  Pohjois-Lappi        197.0        Utsjoki           890.0
# 1678        19.0  Pohjois-Lappi        197.0        Utsjoki           890.0
#
#       latitude  longitude  accuracy
# 0      60.1714    24.9316       6.0
# 1      60.1632    24.9391       6.0
# 2      60.1645    24.9487       6.0
# 3      60.1578    24.9525       6.0
# 4      60.1570    24.9369       6.0
# ...        ...        ...       ...
# 1674   68.4230    27.3965       6.0
# 1675   68.9287    26.9896       6.0
# 1676   69.4918    28.5786       4.0
# 1677   69.4729    25.9527       4.0
# 1678   69.8467    26.8907       6.0
#
# [1679 rows x 12 columns]

# %%
cond = location['latitude'].isna()
jalla = location.assign(cond1= cond)
jalla
# Out:
#      postal_code country_code                      place_name state_name  \
# 0          00100           FI  Helsinki                          Uusimaa
# 1          00120           FI  Helsinki                          Uusimaa
# 2          00130           FI  Helsinki                          Uusimaa
# 3          00140           FI  Helsinki                          Uusimaa
# 4          00150           FI  Helsinki                          Uusimaa
# ...          ...          ...                             ...        ...
# 1674       99830           FI                      Saariselkä    Lapland
# 1675       99870           FI                           Inari    Lapland
# 1676       99930           FI                    Sevettijärvi    Lapland
# 1677       99950           FI                    Karigasniemi    Lapland
# 1678       99980           FI                         Utsjoki    Lapland
#
#       state_code    county_name  county_code community_name  community_code  \
# 0            1.0       Helsinki         11.0       Helsinki            91.0
# 1            1.0       Helsinki         11.0       Helsinki            91.0
# 2            1.0       Helsinki         11.0       Helsinki            91.0
# 3            1.0       Helsinki         11.0       Helsinki            91.0
# 4            1.0       Helsinki         11.0       Helsinki            91.0
# ...          ...            ...          ...            ...             ...
# 1674        19.0  Pohjois-Lappi        197.0          Inari           148.0
# 1675        19.0  Pohjois-Lappi        197.0          Inari           148.0
# 1676        19.0  Pohjois-Lappi        197.0          Inari           148.0
# 1677        19.0  Pohjois-Lappi        197.0        Utsjoki           890.0
# 1678        19.0  Pohjois-Lappi        197.0        Utsjoki           890.0
#
#       latitude  longitude  accuracy  cond1
# 0      60.1714    24.9316       6.0  False
# 1      60.1632    24.9391       6.0  False
# 2      60.1645    24.9487       6.0  False
# 3      60.1578    24.9525       6.0  False
# 4      60.1570    24.9369       6.0  False
# ...        ...        ...       ...    ...
# 1674   68.4230    27.3965       6.0  False
# 1675   68.9287    26.9896       6.0  False
# 1676   69.4918    28.5786       4.0  False
# 1677   69.4729    25.9527       4.0  False
# 1678   69.8467    26.8907       6.0  False
#
# [1679 rows x 13 columns]

# %%
## Find rows which are empty
# Source https://www.kite.com/python/answers/how-to-find-rows-with-nan-values-in-a-pandas-dataframe-in-python


is_NaN = location.isnull()
row_has_NaN = is_NaN.any(axis=1)
rows_with_NaN = location[row_has_NaN]
rows_with_NaN
# Out:
#      postal_code country_code                      place_name  \
# 37         00540           FI  Helsinki
# 289        08450           FI  Lohja
# 294        09120           FI  Karjalohja
# 307        10440           FI  Bollsta
# 317        10710           FI  Snappertuna
# 440        20100           FI  Turku
# 565        25650           FI  Strömma
# 576        26410           FI                           Kaaro
# 852        41350           FI                       Laukaa As
# 859        41530           FI                       Veneranta
# 958        49220           FI  Siltakylä
# 996        52420           FI                     Pellosniemi
# 1186       65460           FI  Tölby
# 1193       65730           FI  Jungsund
# 1215       66550           FI  Västerhankmo
# 1242       68555           FI  Bosund
# 1245       68580           FI  Larsmo
# 1555       91670           FI                           Rokua
# 1590       93999          NaN                             NaN
#
#                      state_name  state_code         county_name  county_code  \
# 37                      Uusimaa         1.0            Helsinki         11.0
# 289                     Uusimaa         1.0            Helsinki         11.0
# 294                     Uusimaa         1.0            Helsinki         11.0
# 307                     Uusimaa         1.0          Raaseporin         14.0
# 317                     Uusimaa         1.0          Raaseporin         14.0
# 440           Southwest Finland         2.0               Turku         23.0
# 565           Southwest Finland         2.0    Åboland-Turunmaa         21.0
# 576                   Satakunta         4.0               Rauma         41.0
# 852      Central Finland Region        13.0           Jyväskylä        131.0
# 859      Central Finland Region        13.0           Jyväskylä        131.0
# 958                 Kymenlaakso         8.0        Kotka-Hamina         82.0
# 996            Southern Savonia        10.0             Mikkeli        101.0
# 1186        Ostrobothnia Region        15.0               Vaasa        152.0
# 1193        Ostrobothnia Region        15.0               Vaasa        152.0
# 1215        Ostrobothnia Region        15.0               Vaasa        152.0
# 1242        Ostrobothnia Region        15.0  Jakobstadsregionen        154.0
# 1245        Ostrobothnia Region        15.0  Jakobstadsregionen        154.0
# 1555  North Ostrobothnia Region        17.0                Oulu        171.0
# 1590                        NaN         NaN                 NaN          NaN
#
#      community_name  community_code  latitude  longitude  accuracy
# 37         Helsinki            91.0   60.1841    24.9785       NaN
# 289           Lohja           444.0   60.2713    23.9952       NaN
# 294           Lohja           444.0   60.2506    23.7101       NaN
# 307        Raseborg           710.0   60.1126    23.5225       NaN
# 317        Raseborg           710.0   59.9782    23.7238       NaN
# 440           Turku           853.0   60.4449    22.2261       NaN
# 565        Kimitoön           322.0   60.1888    22.8499       NaN
# 576           Rauma           684.0   61.1767    21.5183       NaN
# 852          Laukaa           410.0   62.4267    25.8850       NaN
# 859      Hankasalmi            77.0   62.3759    26.3465       NaN
# 958          Pyttis           624.0   60.4556    26.6760       NaN
# 996         Mikkeli           491.0   61.4082    27.4720       NaN
# 1186       Korsholm           499.0   63.0181    21.6953       NaN
# 1193       Korsholm           499.0   63.2036    21.6121       NaN
# 1215       Korsholm           499.0   63.2262    21.8584       NaN
# 1242         Larsmo           440.0   63.8440    22.8238       NaN
# 1245         Larsmo           440.0   63.7104    22.7559       NaN
# 1555          Muhos           494.0   64.5966    26.4537       NaN
# 1590            NaN             NaN       NaN        NaN       NaN

# %%
###. WORK IN PROGRESS (93999 FOR KUUSAMO)
# THIS HAS TO BE ADDED MANUALLY

wanted_features_location = location[["postal_code", 
                                     "place_name", 
                                     "state_name", 
                                     "county_name", 
                                     "latitude", 
                                     "longitude"]]
wanted_features_location = wanted_features_location.rename(columns={"postal_code": "Postal code"})

# %%
df_merge = pd.merge(df4, wanted_features_location, on="Postal code")

# %%
df_merge
# Out:
#        Postal code                      Building type    Quarter       EUR/m2  \
# 0            00100     Blocks of flats, one-room flat 2010-01-01  5458.000000
# 1            00100     Blocks of flats, two-room flat 2010-01-01  5164.000000
# 2            00100  Blocks of flats, three-room flat+ 2010-01-01  4944.000000
# 3            00100              Blocks of flats total 2010-01-01  5168.000000
# 4            00100              Terraced houses total 2010-01-01  1783.222523
# ...            ...                                ...        ...          ...
# 463399       99980     Blocks of flats, two-room flat 2021-01-04  2290.004173
# 463400       99980  Blocks of flats, three-room flat+ 2021-01-04  2290.004173
# 463401       99980              Blocks of flats total 2021-01-04  2290.004173
# 463402       99980              Terraced houses total 2021-01-04  2290.004173
# 463403       99980               Building types total 2021-01-04  2290.004173
#
#                                            Location  \
# 0       Helsinki Keskusta - Etu-Töölö   (Helsinki )
# 1       Helsinki Keskusta - Etu-Töölö   (Helsinki )
# 2       Helsinki Keskusta - Etu-Töölö   (Helsinki )
# 3       Helsinki Keskusta - Etu-Töölö   (Helsinki )
# 4       Helsinki Keskusta - Etu-Töölö   (Helsinki )
# ...                                             ...
# 463399                  Utsjoki Keskus   (Utsjoki )
# 463400                  Utsjoki Keskus   (Utsjoki )
# 463401                  Utsjoki Keskus   (Utsjoki )
# 463402                  Utsjoki Keskus   (Utsjoki )
# 463403                  Utsjoki Keskus   (Utsjoki )
#
#                             place_name state_name    county_name  latitude  \
# 0       Helsinki                          Uusimaa       Helsinki   60.1714
# 1       Helsinki                          Uusimaa       Helsinki   60.1714
# 2       Helsinki                          Uusimaa       Helsinki   60.1714
# 3       Helsinki                          Uusimaa       Helsinki   60.1714
# 4       Helsinki                          Uusimaa       Helsinki   60.1714
# ...                                ...        ...            ...       ...
# 463399                         Utsjoki    Lapland  Pohjois-Lappi   69.8467
# 463400                         Utsjoki    Lapland  Pohjois-Lappi   69.8467
# 463401                         Utsjoki    Lapland  Pohjois-Lappi   69.8467
# 463402                         Utsjoki    Lapland  Pohjois-Lappi   69.8467
# 463403                         Utsjoki    Lapland  Pohjois-Lappi   69.8467
#
#         longitude
# 0         24.9316
# 1         24.9316
# 2         24.9316
# 3         24.9316
# 4         24.9316
# ...           ...
# 463399    26.8907
# 463400    26.8907
# 463401    26.8907
# 463402    26.8907
# 463403    26.8907
#
# [463404 rows x 10 columns]

# %%
#Some columns are missing their geolocation features :(

for i in range(df_merge.shape[1]):
    n_miss = df_merge.iloc[:,i].isnull().sum()
    perc = n_miss / df1.shape[0] * 100
    print('> %d, Missing: %d (%.1f%%)' % (i, n_miss, perc))
# Out:
# > 0, Missing: 0 (0.0%)
# > 1, Missing: 0 (0.0%)
# > 2, Missing: 0 (0.0%)
# > 3, Missing: 0 (0.0%)
# > 4, Missing: 0 (0.0%)
# > 5, Missing: 276 (2.7%)
# > 6, Missing: 276 (2.7%)
# > 7, Missing: 276 (2.7%)
# > 8, Missing: 276 (2.7%)
# > 9, Missing: 276 (2.7%)

# %%
df_merge
# Out:
#        Postal code                      Building type    Quarter       EUR/m2  \
# 0            00100     Blocks of flats, one-room flat 2010-01-01  5458.000000
# 1            00100     Blocks of flats, two-room flat 2010-01-01  5164.000000
# 2            00100  Blocks of flats, three-room flat+ 2010-01-01  4944.000000
# 3            00100              Blocks of flats total 2010-01-01  5168.000000
# 4            00100              Terraced houses total 2010-01-01  1783.222523
# ...            ...                                ...        ...          ...
# 463399       99980     Blocks of flats, two-room flat 2021-01-04  2290.004173
# 463400       99980  Blocks of flats, three-room flat+ 2021-01-04  2290.004173
# 463401       99980              Blocks of flats total 2021-01-04  2290.004173
# 463402       99980              Terraced houses total 2021-01-04  2290.004173
# 463403       99980               Building types total 2021-01-04  2290.004173
#
#                                            Location  \
# 0       Helsinki Keskusta - Etu-Töölö   (Helsinki )
# 1       Helsinki Keskusta - Etu-Töölö   (Helsinki )
# 2       Helsinki Keskusta - Etu-Töölö   (Helsinki )
# 3       Helsinki Keskusta - Etu-Töölö   (Helsinki )
# 4       Helsinki Keskusta - Etu-Töölö   (Helsinki )
# ...                                             ...
# 463399                  Utsjoki Keskus   (Utsjoki )
# 463400                  Utsjoki Keskus   (Utsjoki )
# 463401                  Utsjoki Keskus   (Utsjoki )
# 463402                  Utsjoki Keskus   (Utsjoki )
# 463403                  Utsjoki Keskus   (Utsjoki )
#
#                             place_name state_name    county_name  latitude  \
# 0       Helsinki                          Uusimaa       Helsinki   60.1714
# 1       Helsinki                          Uusimaa       Helsinki   60.1714
# 2       Helsinki                          Uusimaa       Helsinki   60.1714
# 3       Helsinki                          Uusimaa       Helsinki   60.1714
# 4       Helsinki                          Uusimaa       Helsinki   60.1714
# ...                                ...        ...            ...       ...
# 463399                         Utsjoki    Lapland  Pohjois-Lappi   69.8467
# 463400                         Utsjoki    Lapland  Pohjois-Lappi   69.8467
# 463401                         Utsjoki    Lapland  Pohjois-Lappi   69.8467
# 463402                         Utsjoki    Lapland  Pohjois-Lappi   69.8467
# 463403                         Utsjoki    Lapland  Pohjois-Lappi   69.8467
#
#         longitude
# 0         24.9316
# 1         24.9316
# 2         24.9316
# 3         24.9316
# 4         24.9316
# ...           ...
# 463399    26.8907
# 463400    26.8907
# 463401    26.8907
# 463402    26.8907
# 463403    26.8907
#
# [463404 rows x 10 columns]

# %%
one_str = "Blocks of flats, one-room flat"
two_str = "Blocks of flats, two-room flat"
three_str = "Blocks of flats, three-room flat+"
tot_str = "Blocks of flats total"

# %%
d = df_merge[df_merge["Building type"] == tot_str]

# %%
dg = d.groupby(["state_name", "Quarter" ])["EUR/m2"].mean()

# %%
dg = pd.DataFrame(dg)

# %%
dg.head()
# Out:
#                                         EUR/m2
# state_name             Quarter
# Central Finland Region 2010-01-01  1637.989108
#                        2010-01-04  1677.699583
#                        2010-01-07  1688.514182
#                        2010-01-10  1679.362207
#                        2011-01-01  1715.573078

# %%
ax = dg.unstack().T.plot(figsize=(15,10))

# %%
du = d[(d["state_name"] == "Uusimaa")]

# %%
import seaborn as sns

# %%
plt.figure(figsize=(12,6))
ax = sns.boxplot(x="state_name", y="EUR/m2", data=d, showmeans=True)
ax.set_xticklabels(ax.get_xticklabels(), rotation=90)
# Out:
# [Text(0, 0, 'Uusimaa'),
#  Text(0, 0, 'Kanta-Häme'),
#  Text(0, 0, 'Pirkanmaa'),
#  Text(0, 0, 'Päijänne Tavastia'),
#  Text(0, 0, 'Central Finland Region'),
#  Text(0, 0, 'Kymenlaakso'),
#  Text(0, 0, 'Southern Savonia'),
#  Text(0, 0, 'Southwest Finland'),
#  Text(0, 0, 'Satakunta'),
#  Text(0, 0, 'South Karelia'),
#  Text(0, 0, 'North Karelia'),
#  Text(0, 0, 'South Ostrobothnia Region'),
#  Text(0, 0, 'Ostrobothnia Region'),
#  Text(0, 0, 'Central Ostrobothnia Region'),
#  Text(0, 0, 'North Ostrobothnia Region'),
#  Text(0, 0, 'Northern Savo'),
#  Text(0, 0, 'Kainuu'),
#  Text(0, 0, 'Lapland')]

# %%
d2 = d[d["Quarter"].dt.year == 2020]

# %%
d2
# Out:
#        Postal code          Building type    Quarter       EUR/m2  \
# 243          00100  Blocks of flats total 2020-01-01  7460.000000
# 249          00100  Blocks of flats total 2020-01-04  7275.000000
# 255          00100  Blocks of flats total 2020-01-07  8058.000000
# 261          00100  Blocks of flats total 2020-01-10  7540.000000
# 519          00120  Blocks of flats total 2020-01-01  7996.326068
# 525          00120  Blocks of flats total 2020-01-04  8216.000000
# 531          00120  Blocks of flats total 2020-01-07  8393.000000
# 537          00120  Blocks of flats total 2020-01-10  8347.262672
helsinki Keskusta - Etu-Töölö   (Helsinki )
# 249     Helsinki Keskusta - Etu-Töölö   (Helsinki )
# 255     Helsinki Keskusta - Etu-Töölö   (Helsinki )
# 261     Helsinki Keskusta - Etu-Töölö   (Helsinki )
# 519                         Punavuori   (Helsinki )
# 525                         Punavuori   (Helsinki )
# 531                         Punavuori   (Helsinki )
# 537                         Punavuori   (Helsinki )
# 795                   Kaartinkaupunki   (Helsinki )
# 801                   Kaartinkaupunki   (Helsinki )
# 807                   Kaartinkaupunki   (Helsinki )
# 813                   Kaartinkaupunki   (Helsinki )
# 1071         Kaivopuisto - Ullanlinna   (Helsinki )
# 1077         Kaivopuisto - Ullanlinna   (Helsinki )
# 1083         Kaivopuisto - Ullanlinna   (Helsinki )
# 1089         Kaivopuisto - Ullanlinna   (Helsinki )
# 1347                Eira - Hernesaari   (Helsinki )
# 1353                Eira - Hernesaari   (Helsinki )
# 1359                Eira - Hernesaari   (Helsinki )
# 1365                Eira - Hernesaari   (Helsinki )
# 1623                      Katajanokka   (Helsinki )
# 1629                      Katajanokka   (Helsinki )
# 1635                      Katajanokka   (Helsinki )
# 1641                      Katajanokka   (Helsinki )
# 1899                      Kruununhaka   (Helsinki )
# 1905                      Kruununhaka   (Helsinki )
# 1911                      Kruununhaka   (Helsinki )
# 1917                      Kruununhaka   (Helsinki )
# 2175              Kamppi - Ruoholahti   (Helsinki )
# 2181              Kamppi - Ruoholahti   (Helsinki )
# ...                                             ...
# 461451                        Vuotso   (Sodankylä )
# 461457                        Vuotso   (Sodankylä )
# 461715                    Vaalajärvi   (Sodankylä )
# 461721                    Vaalajärvi   (Sodankylä )
# 461727                    Vaalajärvi   (Sodankylä )
# 461733                    Vaalajärvi   (Sodankylä )
# 461991                             Ivalo   (Inari )
# 461997                             Ivalo   (Inari )
# 462003                             Ivalo   (Inari )
# 462009                             Ivalo   (Inari )
# 462267                        Saariselkä   (Inari )
# 462273                        Saariselkä   (Inari )
# 462279                        Saariselkä   (Inari )
# 462285                        Saariselkä   (Inari )
# 462543           Inari Keskus-Lemmenjoki   (Inari )
# 462549           Inari Keskus-Lemmenjoki   (Inari )
# 462555           Inari Keskus-Lemmenjoki   (Inari )
# 462561           Inari Keskus-Lemmenjoki   (Inari )
# 462819              Sevettijärvi-Näätämö   (Inari )
# 462825              Sevettijärvi-Näätämö   (Inari )
# 462831              Sevettijärvi-Näätämö   (Inari )
# 462837              Sevettijärvi-Näätämö   (Inari )
# 463095                    Karigasniemi   (Utsjoki )
# 463101                    Karigasniemi   (Utsjoki )
# 463107                    Karigasniemi   (Utsjoki )
# 463113                    Karigasniemi   (Utsjoki )
# 463371                  Utsjoki Keskus   (Utsjoki )
# 463377                  Utsjoki Keskus   (Utsjoki )
# 463383                  Utsjoki Keskus   (Utsjoki )
# 463389                  Utsjoki Keskus   (Utsjoki )
#
#                             place_name state_name    county_name  latitude  \
# 243     Helsinki                          Uusimaa       Helsinki   60.1714
# 249     Helsinki                          Uusimaa       Helsinki   60.1714
# 255     Helsinki                          Uusimaa       Helsinki   60.1714
# 261     Helsinki                          Uusimaa       Helsinki   60.1714
         Utsjoki    Lapland  Pohjois-Lappi   69.8467
# 463377                         Utsjoki    Lapland  Pohjois-Lappi   69.8467
# 463383                         Utsjoki    Lapland  Pohjois-Lappi   69.8467
# 463389                         Utsjoki    Lapland  Pohjois-Lappi   69.8467
#
#         longitude
# 243       24.9316
# 249       24.9316
# 255       24.9316
# 261       24.9316
# 519       24.9391
# 525       24.9391
# 531       24.9391
# 537       24.9391
# 795       24.9487
# 801       24.9487
# 807       24.9487
# 813       24.9487
# 1071      24.9525
# 1077      24.9525
# 1083      24.9525
# 1089      24.9525
# 1347      24.9369
# 1353      24.9369
# 1359      24.9369
# 1365      24.9369
# 1623      24.9684
# 1629      24.9684
# 1635      24.9684
# 1641      24.9684
# 1899      24.9554
# 1905      24.9554
# 1911      24.9554
# 1917      24.9554
# 2175      24.9190
# 2181      24.9190
# ...           ...
# 461451    27.1706
# 461457    27.1706
# 461715    26.1876
# 461721    26.1876
# 461727    26.1876
# 461733    26.1876
# 461991    27.5968
# 461997    27.5968
# 462003    27.5968
# 462009    27.5968
# 462267    27.3965
# 462273    27.3965
# 462279    27.3965
# 462285    27.3965
# 462543    26.9896
# 462549    26.9896
# 462555    26.9896
# 462561    26.9896
# 462819    28.5786
# 462825    28.5786
# 462831    28.5786
# 462837    28.5786
# 463095    25.9527
# 463101    25.9527
# 463107    25.9527
# 463113    25.9527
# 463371    26.8907
# 463377    26.8907
# 463383    26.8907
# 463389    26.8907
#
# [6716 rows x 10 columns]

# %%
plt.figure(figsize=(12,6))
ax = sns.boxplot(x="state_name", y="EUR/m2", data=d2, showmeans=True)
ax.set_xticklabels(ax.get_xticklabels(), rotation=90)
# Out:
# [Text(0, 0, 'Uusimaa'),
#  Text(0, 0, 'Kanta-Häme'),
#  Text(0, 0, 'Pirkanmaa'),
#  Text(0, 0, 'Päijänne Tavastia'),
#  Text(0, 0, 'Central Finland Region'),
#  Text(0, 0, 'Kymenlaakso'),
#  Text(0, 0, 'Southern Savonia'),
#  Text(0, 0, 'Southwest Finland'),
#  Text(0, 0, 'Satakunta'),
#  Text(0, 0, 'South Karelia'),
#  Text(0, 0, 'North Karelia'),
#  Text(0, 0, 'South Ostrobothnia Region'),
#  Text(0, 0, 'Ostrobothnia Region'),
#  Text(0, 0, 'Central Ostrobothnia Region'),
#  Text(0, 0, 'North Ostrobothnia Region'),
#  Text(0, 0, 'Northern Savo'),
#  Text(0, 0, 'Kainuu'),
#  Text(0, 0, 'Lapland')]

# %%
sns.distplot(d2u["EUR/m2"])

# %%
len(list(d2u.place_name.drop_duplicates()))
# Out:
# 115

# %%
d2u.groupby("place_name")["EUR/m2"].mean()
# Out:
# place_name
# Askola                            2224.795401
# Bollsta                           2224.795401
# Bromarv                           2224.795401
# Dragsvik                          2224.795401
# Emäsalo                           2224.795401
# Espoo                             3231.749970
# Evitskog                          2224.795401
# Fiskari                           2224.795401
# Haarajoki                         2224.795401
# Halkia                            2224.795401
# Hamari                            2224.795401
# Hangonkylä                        2224.795401
# Hanko                             1541.137919
# Hanko Pohjoinen                   2224.795401
# Hautjärvi                         2224.795401
# Helsinki                          4613.111235
# Hinthaara                         2224.795401
# Hirvihaara                        2224.795401
# Huhmari                           2224.795401
# Huuvari                           2224.795401
# Hyvinkää                          1836.490507
# Ikkala                            2224.795401
# Ilola                             2224.795401
# Inkoo                             2224.795401
# Isnäs                             2224.795401
# Jokela                            1877.552221
# Jorvas                            2224.795401
# Jäniksenlinna                     2224.795401
# Järvenpää                         2336.252485
# Kantvik                           2036.242225
#                                      ...
# Ruotsinkylä                       2224.795401
# Ruotsinpyhtää                     2224.795401
# Röykkä                            2224.795401
# Saarentaus                        2224.795401
# Sammatti                          2224.795401
# Sarvvik                           2224.795401
# Saukkola                          2224.795401
# Selki                             2224.795401
# Sipoo                             2223.241236
# Siuntio                           2224.795401
# Siuntio Kk                        2224.795401
# Skinnarby                         2224.795401
# Skogby                            2224.795401
# Snappertuna                       2224.795401
# Sundsberg                         2224.795401
# Söderkulla                        2611.873366
# Talma                             2224.795401
# Tammisaari                        1806.219370
# Tenhola                           2224.795401
# Tesjoki                           2224.795401
# Tolkkinen                         2224.795401
# Torppi                            2224.795401
# Tuusula                           2092.338446
# Vakkola                           2224.795401
# Valko                             2224.795401
# Vantaa                            2666.787825
# Veikkola                          2224.795401
# Vihti                             2010.442590
# Västerskog                        2224.795401
# Åminnefors                        2224.795401
# Name: EUR/m2, Length: 115, dtype: float64

# %%
sns.distplot(d2[(d2["state_name"] == "Kainuu")]["EUR/m2"])

# %%
d3 = df_merge[df_merge["Building type"].isin([one_str, two_str, three_str])]

# %%
d3
# Out:
#        Postal code                      Building type    Quarter       EUR/m2  \
# 0            00100     Blocks of flats, one-room flat 2010-01-01  5458.000000
# 1            00100     Blocks of flats, two-room flat 2010-01-01  5164.000000
# 2            00100  Blocks of flats, three-room flat+ 2010-01-01  4944.000000
# 6            00100     Blocks of flats, one-room flat 2010-01-04  5347.000000
# 7            00100     Blocks of flats, two-room flat 2010-01-04  5021.000000
# 8            00100  Blocks of flats, three-room flat+ 2010-01-04  5396.000000
# 12           00100     Blocks of flats, one-room flat 2010-01-07  5826.000000
# 13           00100     Blocks of flats, two-room flat 2010-01-07  5081.000000
# 14           00100  Blocks of flats, three-room flat+ 2010-01-07  4828.000000
# 18           00100     Blocks of flats, one-room flat 2010-01-10  5566.000000
# 19           00100     Blocks of flats, two-room flat 2010-01-10  5006.000000
# 20           00100  Blocks of flats, three-room flat+ 2010-01-10  5394.000000
# 24           00100     Blocks of flats, one-room flat 2011-01-01  5545.000000
# 25           00100     Blocks of flats, two-room flat 2011-01-01  5713.000000
# 26           00100  Blocks of flats, three-room flat+ 2011-01-01  5571.000000
# 30           00100     Blocks of flats, one-room flat 2011-01-04  5812.000000
# 31           00100     Blocks of flats, two-room flat 2011-01-04  5866.000000
# 32           00100  Blocks of flats, three-room flat+ 2011-01-04  5709.000000
# 36           00100     Blocks of flats, one-room flat 2011-01-07  5909.000000
# 37           00100     Blocks of flats, two-room flat 2011-01-07  5552.000000
# 38           00100  Blocks of flats, three-room flat+ 2011-01-07  5450.000000
         Utsjoki    Lapland  Pohjois-Lappi   69.8467
# 463345                         Utsjoki    Lapland  Pohjois-Lappi   69.8467
# 463346                         Utsjoki    Lapland  Pohjois-Lappi   69.8467
# 463350                         Utsjoki    Lapland  Pohjois-Lappi   69.8467
# 463351                         Utsjoki    Lapland  Pohjois-Lappi   69.8467
# 463352                         Utsjoki    Lapland  Pohjois-Lappi   69.8467
# 463356                         Utsjoki    Lapland  Pohjois-Lappi   69.8467
# 463357                         Utsjoki    Lapland  Pohjois-Lappi   69.8467
# 463358                         Utsjoki    Lapland  Pohjois-Lappi   69.8467
# 463362                         Utsjoki    Lapland  Pohjois-Lappi   69.8467
# 463363                         Utsjoki    Lapland  Pohjois-Lappi   69.8467
# 463364                         Utsjoki    Lapland  Pohjois-Lappi   69.8467
# 463368                         Utsjoki    Lapland  Pohjois-Lappi   69.8467
# 463369                         Utsjoki    Lapland  Pohjois-Lappi   69.8467
# 463370                         Utsjoki    Lapland  Pohjois-Lappi   69.8467
# 463374                         Utsjoki    Lapland  Pohjois-Lappi   69.8467
# 463375                         Utsjoki    Lapland  Pohjois-Lappi   69.8467
# 463376                         Utsjoki    Lapland  Pohjois-Lappi   69.8467
# 463380                         Utsjoki    Lapland  Pohjois-Lappi   69.8467
# 463381                         Utsjoki    Lapland  Pohjois-Lappi   69.8467
# 463382                         Utsjoki    Lapland  Pohjois-Lappi   69.8467
# 463386                         Utsjoki    Lapland  Pohjois-Lappi   69.8467
# 463387                         Utsjoki    Lapland  Pohjois-Lappi   69.8467
# 463388                         Utsjoki    Lapland  Pohjois-Lappi   69.8467
# 463392                         Utsjoki    Lapland  Pohjois-Lappi   69.8467
# 463393                         Utsjoki    Lapland  Pohjois-Lappi   69.8467
# 463394                         Utsjoki    Lapland  Pohjois-Lappi   69.8467
# 463398                         Utsjoki    Lapland  Pohjois-Lappi   69.8467
# 463399                         Utsjoki    Lapland  Pohjois-Lappi   69.8467
# 463400                         Utsjoki    Lapland  Pohjois-Lappi   69.8467
#
#         longitude
# 0         24.9316
# 1         24.9316
# 2         24.9316
# 6         24.9316
# 7         24.9316
# 8         24.9316
# 12        24.9316
# 13        24.9316
# 14        24.9316
# 18        24.9316
# 19        24.9316
# 20        24.9316
# 24        24.9316
# 25        24.9316
# 26        24.9316
# 30        24.9316
# 31        24.9316
# 32        24.9316
# 36        24.9316
# 37        24.9316
# 38        24.9316
# 42        24.9316
# 43        24.9316
# 44        24.9316
# 48        24.9316
# 49        24.9316
# 50        24.9316
# 54        24.9316
# 55        24.9316
# 56        24.9316
# ...           ...
# 463344    26.8907
# 463345    26.8907
# 463346    26.8907
# 463350    26.8907
# 463351    26.8907
# 463352    26.8907
# 463356    26.8907
# 463357    26.8907
# 463358    26.8907
# 463362    26.8907
# 463363    26.8907
# 463364    26.8907
# 463368    26.8907
# 463369    26.8907
# 463370    26.8907
# 463374    26.8907
# 463375    26.8907
# 463376    26.8907
# 463380    26.8907
# 463381    26.8907
# 463382    26.8907
# 463386    26.8907
# 463387    26.8907
# 463388    26.8907
# 463392    26.8907
# 463393    26.8907
# 463394    26.8907
# 463398    26.8907
# 463399    26.8907
# 463400    26.8907
#
# [231702 rows x 10 columns]

# %%
plt.figure(figsize=(12,6))
ax = sns.boxplot(x="state_name", y="EUR/m2", data=d3, hue="Building type", showmeans=True)
ax.set_xticklabels(ax.get_xticklabels(), rotation=90)
# Out:
# [Text(0, 0, 'Uusimaa'),
#  Text(0, 0, 'Kanta-Häme'),
#  Text(0, 0, 'Pirkanmaa'),
#  Text(0, 0, 'Päijänne Tavastia'),
#  Text(0, 0, 'Central Finland Region'),
#  Text(0, 0, 'Kymenlaakso'),
#  Text(0, 0, 'Southern Savonia'),
#  Text(0, 0, 'Southwest Finland'),
#  Text(0, 0, 'Satakunta'),
#  Text(0, 0, 'South Karelia'),
#  Text(0, 0, 'North Karelia'),
#  Text(0, 0, 'South Ostrobothnia Region'),
#  Text(0, 0, 'Ostrobothnia Region'),
#  Text(0, 0, 'Central Ostrobothnia Region'),
#  Text(0, 0, 'North Ostrobothnia Region'),
#  Text(0, 0, 'Northern Savo'),
#  Text(0, 0, 'Kainuu'),
#  Text(0, 0, 'Lapland')]

# %%
sns.heatmap(df_imp.groupby("Building type").mean().T.corr())

# %%
df_merge["year"] = df_merge.Quarter.dt.year

# %%
df_year = {}
for year in range(2010, 2021):
    print(len(np.array(list(df_merge[df_merge["year"] == year]["EUR/m2"]))))
    df_year[year] = np.array(list(df_merge[df_merge["year"] == year]["EUR/m2"]))
df_year = pd.DataFrame(df_year)
# Out:
# 40296
# 40296
# 40296
# 40296
# 40296
# 40296
# 40296
# 40296
# 40296
# 40296
# 40296

# %%
sns.heatmap(df_year.corr())

# %%
du.plot(kind="scatter", x="longitude", y="latitude", alpha=0.2, figsize=(15,20),
 c="EUR/m2", cmap=plt.get_cmap("jet"), colorbar=True,
)
plt.legend()
# Out:
# No handles with labels found to put in legend.

# %%
states = list(d3["state_name"].drop_duplicates())

# %%
dd = pd.DataFrame()
for state in states:
    dd[state] = d3[d3["state_name"] == state]["EUR/m2"]

# %% [markdown]
# ## Value of square meter of cities Q2 2021

# %%
Q2_2021__one_room = df_merge[(df_merge["Quarter"] == "2021-01-04") & (df_merge["Building type"] == "Blocks of flats, one-room flat")]

# %%
Q2_2021__one_room
# Out:
#        Postal code                   Building type    Quarter        EUR/m2  \
# 270          00100  Blocks of flats, one-room flat 2021-01-04   8596.000000
# 546          00120  Blocks of flats, one-room flat 2021-01-04   8549.699924
# 822          00130  Blocks of flats, one-room flat 2021-01-04   2290.004173
# 1098         00140  Blocks of flats, one-room flat 2021-01-04  10025.116718
# 1374         00150  Blocks of flats, one-room flat 2021-01-04   9420.000000
# ...            ...                             ...        ...           ...
# 462294       99830  Blocks of flats, one-room flat 2021-01-04   2290.004173
# 462570       99870  Blocks of flats, one-room flat 2021-01-04   2290.004173
# 462846       99930  Blocks of flats, one-room flat 2021-01-04   2290.004173
# 463122       99950  Blocks of flats, one-room flat 2021-01-04   2290.004173
# 463398       99980  Blocks of flats, one-room flat 2021-01-04   2290.004173
#
#                                            Location  \
# 270     Helsinki Keskusta - Etu-Töölö   (Helsinki )
# 546                         Punavuori   (Helsinki )
# 822                   Kaartinkaupunki   (Helsinki )
# 1098         Kaivopuisto - Ullanlinna   (Helsinki )
# 1374                Eira - Hernesaari   (Helsinki )
# ...                                             ...
# 462294                        Saariselkä   (Inari )
# 462570           Inari Keskus-Lemmenjoki   (Inari )
# 462846              Sevettijärvi-Näätämö   (Inari )
# 463122                    Karigasniemi   (Utsjoki )
# 463398                  Utsjoki Keskus   (Utsjoki )
#
#                             place_name state_name    county_name  latitude  \
# 270     Helsinki                          Uusimaa       Helsinki   60.1714
# 546     Helsinki                          Uusimaa       Helsinki   60.1632
# 822     Helsinki                          Uusimaa       Helsinki   60.1645
# 1098    Helsinki                          Uusimaa       Helsinki   60.1578
# 1374    Helsinki                          Uusimaa       Helsinki   60.1570
# ...                                ...        ...            ...       ...
# 462294                      Saariselkä    Lapland  Pohjois-Lappi   68.4230
# 462570                           Inari    Lapland  Pohjois-Lappi   68.9287
# 462846                    Sevettijärvi    Lapland  Pohjois-Lappi   69.4918
# 463122                    Karigasniemi    Lapland  Pohjois-Lappi   69.4729
# 463398                         Utsjoki    Lapland  Pohjois-Lappi   69.8467
#
#         longitude
# 270       24.9316
# 546       24.9391
# 822       24.9487
# 1098      24.9525
# 1374      24.9369
# ...           ...
# 462294    27.3965
# 462570    26.9896
# 462846    28.5786
# 463122    25.9527
# 463398    26.8907
#
# [1679 rows x 10 columns]

# %%
Q2_2021__one_room.plot(kind="scatter", x="longitude", y="latitude", alpha=0.2, figsize=(15,20),
 c="EUR/m2", cmap=plt.get_cmap("jet"), colorbar=True,
)
plt.legend()
# Out:
# No handles with labels found to put in legend.
