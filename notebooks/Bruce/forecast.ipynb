# %%
# Basic imports
import numpy as np
import pandas as pd
import datetime # manipulating date formats
import itertools
import time
from matplotlib import pyplot as plt
from sklearn.metrics import mean_squared_error as MSE, r2_score, mean_absolute_percentage_error as MAPE

# Stats packages
from statsmodels.tsa.statespace.varmax import VARMAX
from statsmodels.tsa.statespace.sarimax import SARIMAX
from statsmodels.tsa.seasonal import seasonal_decompose,STL
from statsmodels.tsa.stattools import adfuller
from statsmodels.tsa.statespace.tools import diff
from statsmodels.graphics.tsaplots import plot_acf,plot_pacf
import statsmodels.api as sm

import warnings
warnings.filterwarnings("ignore")

# %%
df = pd.read_csv("imputed_df.csv", index_col=0,parse_dates=[0])
df.head()
# Out:
#             (100, 'Blocks of flats, one-room flat')  \
# 2010-04-01                                     5347
# 2010-07-01                                     5826
# 2010-10-01                                     5566
# 2011-01-01                                     5545
# 2011-04-01                                     5812
#
#             (100, 'Blocks of flats, two-room flat')  \
# 2010-04-01                                     5021
# 2010-07-01                                     5081
# 2010-10-01                                     5006
# 2011-01-01                                     5713
# 2011-04-01                                     5866
#
#             (100, 'Blocks of flats, three-room flat+')  \
# 2010-04-01                                        5396
# 2010-07-01                                        4828
# 2010-10-01                                        5394
# 2011-01-01                                        5571
# 2011-04-01                                        5709
#
#             (100, 'Blocks of flats total')  (100, 'Building types total')  \
# 2010-04-01                            5219                           5219
# 2010-07-01                            5181                           5181
# 2010-10-01                            5269                           5269
# 2011-01-01                            5632                           5632
# 2011-04-01                            5807                           5807
#
#             (120, 'Blocks of flats, one-room flat')  \
# 2010-04-01                                     5646
# 2010-07-01                                     5395
# 2010-10-01                                     5613
# 2011-01-01                                     5905
# 2011-04-01                                     6332
#
#             (120, 'Blocks of flats, two-room flat')  \
# 2010-04-01                                     5355
# 2010-07-01                                     5534
# 2010-10-01                                     5321
# 2011-01-01                                     5528
# 2011-04-01                                     5523
#
#             (120, 'Blocks of flats, three-room flat+')  \
# 2010-04-01                                        5713
# 2010-07-01                                        5884
# 2010-10-01                                        5666
# 2011-01-01                                        5691
# 2011-04-01                                        5571
#
#             (120, 'Blocks of flats total')  (120, 'Building types total')  \
# 2010-04-01                            5495                           5495
# 2010-07-01                            5595                           5595
# 2010-10-01                            5521                           5521
# 2011-01-01                            5689                           5689
# 2011-04-01                            5749                           5749
#
#             ...  (96200, 'Building types total')  \
# 2010-04-01  ...                             1646
# 2010-07-01  ...                             1668
# 2010-10-01  ...                             1619
# 2011-01-01  ...                             1631
# 2011-04-01  ...                             1906
#
#             (96300, 'Blocks of flats, two-room flat')  \
# 2010-04-01                                       1525
# 2010-07-01                                       1794
# 2010-10-01                                       1670
# 2011-01-01                                       1501
# 2011-04-01                                       1713
#
#             (96300, 'Building types total')  (96400, 'Building types total')  \
# 2010-04-01                             1475                             1499
# 2010-07-01                             1782                             1614
# 2010-10-01                             1750                             1826
# 2011-01-01                             1678                             1697
# 2011-04-01                             1672                             1565
#
#             (96440, 'Building types total')  (96460, 'Building types total')  \
# 2010-04-01                             1109                             1568
# 2010-07-01                             1069                             1568
# 2010-10-01                              929                             1568
# 2011-01-01                             1195                             1615
# 2011-04-01                              932                             1657
#
#             (96500, 'Building types total')  (96900, 'Building types total')  \
# 2010-04-01                             1039                             2030
# 2010-07-01                             1069                             1519
# 2010-10-01                             1028                             1839
# 2011-01-01                             1146                             1868
# 2011-04-01                             1097                             1729
#
#             (96910, 'Building types total')  (99600, 'Building types total')
# 2010-04-01                             1404                             1059
# 2010-07-01                             1354                              836
# 2010-10-01                             1462                              972
# 2011-01-01                             1445                              737
# 2011-04-01                             1544                              932
#
# [5 rows x 1193 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 45 entries, 2010-04-01 to 2021-04-01
# Columns: 1193 entries, (100, 'Blocks of flats, one-room flat') to (99600, 'Building types total')
# dtypes: int64(1193)
# memory usage: 419.8 KB

# %%
def params_search(tgt_dict, named_ts, max_p=2, d=1, max_q=2, max_P=2, D=1, max_Q=2, s=4):
    """
    Keyword arguments:
    multivar_ts -- pandas dataframe of shape (n,m) where n is the number of
    time steps and n is the number of variables for prediction.
    """    
    # set parameter range
    col_name, ts = named_ts
    p,d,q = range(0,max_p+1),[d],range(0,max_q+1)
    P,D,Q,s = range(0,max_P+1),[D],range(0,max_Q+1),[s]
    
    # list of all parameter combos
    pdq = list(itertools.product(p, d, q))
    seasonal_pdq = list(itertools.product(P, D, Q, s))
    all_param = list(itertools.product(pdq,seasonal_pdq))

    best_param, best_aic = all_param[0], np.inf
    for param in all_param:
        try:
            mod = SARIMAX(
                ts,
                order=param[0],
                seasonal_order=param[1]
            )
            res = mod.fit(disp=0)
            if res.aic < best_aic:
                best_param, best_aic = param, res.aic
        except Exception as e:
            print(e)
            continue
    
    print(f'The best model for {col_name} is: SARIMAX{best_param[0]}x{best_param[1]} \
        - AIC:{round(best_aic,2)}')

    tgt_dict[col_name] = best_param
            
    return best_param

# %%
def df_params_search(df, max_p=2, d=1, max_q=2, max_P=2, D=1, max_Q=2, s=4):
    """
    Keyword arguments:
    multivar_ts -- pandas dataframe of shape (n,m) where n is the number of
    time steps and n is the number of variables for prediction.
    """
    res_df = pd.DataFrame(columns=df.columns, index=list('pdqPDQs'))
    # set parameter range
    p,d,q = range(0,max_p+1),[d],range(0,max_q+1)
    P,D,Q,s = range(0,max_P+1),[D],range(0,max_Q+1),[s]

    # list of all parameter combos
    pdq = list(map(list,itertools.product(p, d, q)))
    seasonal_pdq = list(map(list, itertools.product(P, D, Q, s)))
    all_param = list(map(list, itertools.product(pdq,seasonal_pdq)))

    for column in df:
        best_param, best_aic = [[0,0,0],[0,0,0,4]], np.inf
        for param in all_param:
            try:
                mod = SARIMAX(
                    df[column].values,
                    order=param[0],
                    seasonal_order=param[1]
                )
                
                res = mod.fit(disp=0)
                if res.aic < best_aic:
                    best_param, best_aic = param, res.aic
            except Exception as e:
                print(e)
                continue

        res_df[column] = best_param[0] + best_param[1]
    
        print(f'The best model for {column} is: SARIMAX{best_param[0]}x{best_param[1]} \
            - AIC:{round(best_aic,2)}')
            
    return res_df

# %%
res_df = df_params_search(df.iloc[:,:2])
res_df
# Out:
# The best model for (100, 'Blocks of flats, one-room flat') is: SARIMAX[0, 1, 1]x[0, 1, 1, 4]             - AIC:641.14
# The best model for (100, 'Blocks of flats, two-room flat') is: SARIMAX[0, 1, 1]x[0, 1, 1, 4]             - AIC:591.47

# %%
res_df
# Out:
#    (100, 'Blocks of flats, one-room flat')  \
# p                                        0
# d                                        1
# q                                        1
# P                                        0
# D                                        1
# Q                                        1
# s                                        4
#
#    (100, 'Blocks of flats, two-room flat')
# p                                        0
# d                                        1
# q                                        1
# P                                        0
# D                                        1
# Q                                        1
# s                                        4

# %%
from multiprocessing import Pool

def parallelize_dataframe(df, func, n_cores=12):
    df_split = np.array_split(df, n_cores, axis=1)
    pool = Pool(n_cores)
    df = pd.concat(pool.map(func, df_split))
    pool.close()
    pool.join()
    return df

# %%
df = parallelize_dataframe(df.iloc[:,:2], df_params_search)
df.head()
# Out:
# LU decomposition error.
# The best model for (130, 'Building types total') is: SARIMAX[2, 1, 0]x[2, 1, 1, 4]             - AIC:637.64
# LU decomposition error.
# The best model for (150, 'Blocks of flats total') is: SARIMAX[1, 1, 0]x[0, 1, 1, 4]             - AIC:551.24
# The best model for (200, 'Blocks of flats, two-room flat') is: SARIMAX[1, 1, 0]x[0, 1, 1, 4]             - AIC:526.31
# The best model for (160, 'Blocks of flats total') is: SARIMAX[0, 1, 2]x[0, 1, 1, 4]             - AIC:596.98
# The best model for (140, 'Blocks of flats, three-room flat+') is: SARIMAX[0, 1, 1]x[0, 1, 1, 4]             - AIC:610.12
# LU decomposition error.
# The best model for (100, 'Blocks of flats, one-room flat') is: SARIMAX[0, 1, 1]x[0, 1, 1, 4]             - AIC:641.14
# The best model for (150, 'Blocks of flats, one-room flat') is: SARIMAX[1, 1, 0]x[0, 1, 1, 4]             - AIC:584.15
# The best model for (120, 'Blocks of flats total') is: SARIMAX[0, 1, 1]x[0, 1, 1, 4]             - AIC:571.1
# The best model for (100, 'Building types total') is: SARIMAX[0, 1, 1]x[0, 1, 1, 4]             - AIC:599.12
# The best model for (180, 'Blocks of flats, three-room flat+') is: SARIMAX[0, 1, 2]x[1, 1, 2, 4]             - AIC:12.0
# The best model for (170, 'Building types total') is: SARIMAX[0, 1, 1]x[1, 1, 1, 4]             - AIC:552.58
# The best model for (170, 'Blocks of flats, two-room flat') is: SARIMAX[0, 1, 1]x[1, 1, 1, 4]             - AIC:587.92
# The best model for (200, 'Blocks of flats, three-room flat+') is: SARIMAX[2, 1, 0]x[0, 1, 1, 4]             - AIC:547.25
# The best model for (140, 'Blocks of flats total') is: SARIMAX[0, 1, 1]x[0, 1, 1, 4]             - AIC:575.89
# The best model for (140, 'Blocks of flats, one-room flat') is: SARIMAX[0, 1, 1]x[0, 1, 1, 4]             - AIC:596.78
# The best model for (150, 'Building types total') is: SARIMAX[1, 1, 0]x[0, 1, 1, 4]             - AIC:551.88
# The best model for (150, 'Blocks of flats, two-room flat') is: SARIMAX[0, 1, 1]x[0, 1, 2, 4]             - AIC:570.58
# The best model for (100, 'Blocks of flats, two-room flat') is: SARIMAX[0, 1, 1]x[0, 1, 1, 4]             - AIC:591.47
# The best model for (160, 'Building types total') is: SARIMAX[2, 1, 2]x[0, 1, 1, 4]             - AIC:600.94
# The best model for (120, 'Building types total') is: SARIMAX[1, 1, 0]x[0, 1, 1, 4]             - AIC:575.08
# The best model for (180, 'Blocks of flats, one-room flat') is: SARIMAX[1, 1, 1]x[1, 1, 2, 4]             - AIC:12.0
# The best model for (120, 'Blocks of flats, one-room flat') is: SARIMAX[0, 1, 1]x[0, 1, 1, 4]             - AIC:603.71
# The best model for (180, 'Blocks of flats total') is: SARIMAX[0, 1, 1]x[0, 1, 1, 4]             - AIC:575.44
# The best model for (170, 'Blocks of flats, three-room flat+') is: SARIMAX[0, 1, 1]x[0, 1, 1, 4]             - AIC:581.22
# The best model for (200, 'Building types total') is: SARIMAX[1, 1, 0]x[1, 1, 2, 4]             - AIC:508.07
# The best model for (140, 'Building types total') is: SARIMAX[1, 1, 1]x[0, 1, 1, 4]             - AIC:580.75
# The best model for (140, 'Blocks of flats, two-room flat') is: SARIMAX[2, 1, 1]x[2, 1, 2, 4]             - AIC:612.94
# The best model for (160, 'Blocks of flats, three-room flat+') is: SARIMAX[2, 1, 1]x[0, 1, 1, 4]             - AIC:645.92
# The best model for (100, 'Blocks of flats, three-room flat+') is: SARIMAX[1, 1, 0]x[0, 1, 1, 4]             - AIC:588.76
# The best model for (130, 'Blocks of flats total') is: SARIMAX[2, 1, 0]x[2, 1, 1, 4]             - AIC:637.64
# The best model for (150, 'Blocks of flats, three-room flat+') is: SARIMAX[0, 1, 1]x[0, 1, 1, 4]             - AIC:635.39
# The best model for (170, 'Blocks of flats, one-room flat') is: SARIMAX[0, 1, 1]x[0, 1, 1, 4]             - AIC:609.86
# The best model for (180, 'Building types total') is: SARIMAX[1, 1, 1]x[0, 1, 1, 4]             - AIC:581.89
# The best model for (120, 'Blocks of flats, two-room flat') is: SARIMAX[0, 1, 1]x[0, 1, 1, 4]             - AIC:615.94
# The best model for (180, 'Blocks of flats, two-room flat') is: SARIMAX[0, 1, 1]x[0, 1, 1, 4]             - AIC:598.68
# The best model for (170, 'Blocks of flats total') is: SARIMAX[0, 1, 1]x[0, 1, 1, 4]             - AIC:552.97
# LU decomposition error.
# The best model for (100, 'Blocks of flats total') is: SARIMAX[0, 1, 1]x[0, 1, 1, 4]             - AIC:599.12
# The best model for (120, 'Blocks of flats, three-room flat+') is: SARIMAX[0, 1, 1]x[0, 1, 1, 4]             - AIC:601.39
#    (100, 'Blocks of flats, one-room flat')  \
# p                                      0.0
# d                                      1.0
# q                                      1.0
# P                                      0.0
# D                                      1.0
#
#    (100, 'Blocks of flats, two-room flat')  \
# p                                      0.0
# d                                      1.0
# q                                      1.0
# P                                      0.0
# D                                      1.0
#
#    (100, 'Blocks of flats, three-room flat+')  (100, 'Blocks of flats total')  \
# p                                         1.0                             0.0
# d                                         1.0                             1.0
# q                                         0.0                             1.0
# P                                         0.0                             0.0
# D                                         1.0                             1.0
#
#    (100, 'Building types total')  (120, 'Blocks of flats, one-room flat')  \
# p                            NaN                                      NaN
# d                            NaN                                      NaN
# q                            NaN                                      NaN
# P                            NaN                                      NaN
# D                            NaN                                      NaN
#
#    (120, 'Blocks of flats, two-room flat')  \
# p                                      NaN
# d                                      NaN
# q                                      NaN
# P                                      NaN
# D                                      NaN
#
#    (120, 'Blocks of flats, three-room flat+')  (120, 'Blocks of flats total')  \
# p                                         NaN                             NaN
# d                                         NaN                             NaN
# q                                         NaN                             NaN
# P                                         NaN                             NaN
# D                                         NaN                             NaN
#
#    (120, 'Building types total')  ...  (170, 'Blocks of flats total')  \
# p                            NaN  ...                             NaN
# d                            NaN  ...                             NaN
# q                            NaN  ...                             NaN
# P                            NaN  ...                             NaN
# D                            NaN  ...                             NaN
#
#    (170, 'Building types total')  (180, 'Blocks of flats, one-room flat')  \
# p                            NaN                                      NaN
# d                            NaN                                      NaN
# q                            NaN                                      NaN
# P                            NaN                                      NaN
# D                            NaN                                      NaN
#
#    (180, 'Blocks of flats, two-room flat')  \
# p                                      NaN
# d                                      NaN
# q                                      NaN
# P                                      NaN
# D                                      NaN
#
#    (180, 'Blocks of flats, three-room flat+')  (180, 'Blocks of flats total')  \
# p                                         NaN                             NaN
# d                                         NaN                             NaN
# q                                         NaN                             NaN
# P                                         NaN                             NaN
# D                                         NaN                             NaN
#
#    (180, 'Building types total')  (200, 'Blocks of flats, two-room flat')  \
# p                            NaN                                      NaN
# d                            NaN                                      NaN
# q                            NaN                                      NaN
# P                            NaN                                      NaN
# D                            NaN                                      NaN
#
#    (200, 'Blocks of flats, three-room flat+')  (200, 'Building types total')
# p                                         NaN                            NaN
# d                                         NaN                            NaN
# q                                         NaN                            NaN
# P                                         NaN                            NaN
# D                                         NaN                            NaN
#
# [5 rows x 38 columns]

# %%
df_params_search(df.iloc[:,:2])
# Out:
# The best model for (100, 'Blocks of flats, one-room flat') is: SARIMAX[0, 1, 1]x[0, 1, 1, 4]             - AIC:641.14
# The best model for (100, 'Blocks of flats, two-room flat') is: SARIMAX[0, 1, 1]x[0, 1, 1, 4]             - AIC:591.47
#    (100, 'Blocks of flats, one-room flat')  \
# p                                        0
# d                                        1
# q                                        1
# P                                        0
# D                                        1
# Q                                        1
# s                                        4
#
#    (100, 'Blocks of flats, two-room flat')
# p                                        0
# d                                        1
# q                                        1
# P                                        0
# D                                        1
# Q                                        1
# s                                        4

# %%
import multiprocessing as mp
import pprint
from multiprocessing import Pool
from itertools import repeat

res = dict()

if __name__ == '__main__':
    with mp.Manager() as manager:
        d = manager.dict()
        named_ts = df.iloc[:,:38].to_dict(orient='list').items()
        args = list(zip(repeat(d, len(named_ts)), named_ts))
        with manager.Pool() as pool:
            pool.starmap(params_search, args)
        # `d` is a DictProxy object that can be converted to dict
        # pprint.pprint(dict(d))
        res = dict(d)
        pprint.pprint(res)
# Out:
# LU decomposition error.
# The best model for (130, 'Building types total') is: SARIMAX(2, 1, 0)x(2, 1, 1, 4)         - AIC:637.64
# The best model for (130, 'Blocks of flats total') is: SARIMAX(2, 1, 0)x(2, 1, 1, 4)         - AIC:637.64
# The best model for (100, 'Blocks of flats, three-room flat+') is: SARIMAX(1, 1, 0)x(0, 1, 1, 4)         - AIC:588.76
# LU decomposition error.
# The best model for (120, 'Building types total') is: SARIMAX(1, 1, 0)x(0, 1, 1, 4)         - AIC:575.08
# The best model for (100, 'Blocks of flats, two-room flat') is: SARIMAX(0, 1, 1)x(0, 1, 1, 4)         - AIC:591.47
# LU decomposition error.
# LU decomposition error.
# The best model for (120, 'Blocks of flats, three-room flat+') is: SARIMAX(0, 1, 1)x(0, 1, 1, 4)         - AIC:601.39
# The best model for (100, 'Blocks of flats, one-room flat') is: SARIMAX(0, 1, 1)x(0, 1, 1, 4)         - AIC:641.14
# The best model for (120, 'Blocks of flats, one-room flat') is: SARIMAX(0, 1, 1)x(0, 1, 1, 4)         - AIC:603.71
# The best model for (120, 'Blocks of flats total') is: SARIMAX(0, 1, 1)x(0, 1, 1, 4)         - AIC:571.1
# The best model for (120, 'Blocks of flats, two-room flat') is: SARIMAX(0, 1, 1)x(0, 1, 1, 4)         - AIC:615.94
# The best model for (100, 'Blocks of flats total') is: SARIMAX(0, 1, 1)x(0, 1, 1, 4)         - AIC:599.12
# The best model for (100, 'Building types total') is: SARIMAX(0, 1, 1)x(0, 1, 1, 4)         - AIC:599.12
# The best model for (140, 'Blocks of flats total') is: SARIMAX(0, 1, 1)x(0, 1, 1, 4)         - AIC:575.89
# The best model for (140, 'Blocks of flats, one-room flat') is: SARIMAX(0, 1, 1)x(0, 1, 1, 4)         - AIC:596.78
# The best model for (150, 'Blocks of flats, two-room flat') is: SARIMAX(0, 1, 1)x(0, 1, 2, 4)         - AIC:570.58
# The best model for (140, 'Blocks of flats, two-room flat') is: SARIMAX(2, 1, 1)x(2, 1, 2, 4)         - AIC:612.94
# The best model for (140, 'Blocks of flats, three-room flat+') is: SARIMAX(0, 1, 1)x(0, 1, 1, 4)         - AIC:610.12
# The best model for (140, 'Building types total') is: SARIMAX(1, 1, 1)x(0, 1, 1, 4)         - AIC:580.75
# The best model for (150, 'Blocks of flats total') is: SARIMAX(1, 1, 0)x(0, 1, 1, 4)         - AIC:551.24
# The best model for (150, 'Building types total') is: SARIMAX(1, 1, 0)x(0, 1, 1, 4)         - AIC:551.88
# The best model for (150, 'Blocks of flats, one-room flat') is: SARIMAX(1, 1, 0)x(0, 1, 1, 4)         - AIC:584.15
# The best model for (160, 'Blocks of flats, three-room flat+') is: SARIMAX(2, 1, 1)x(0, 1, 1, 4)         - AIC:645.92
# The best model for (160, 'Blocks of flats total') is: SARIMAX(0, 1, 2)x(0, 1, 1, 4)         - AIC:596.98
# The best model for (150, 'Blocks of flats, three-room flat+') is: SARIMAX(0, 1, 1)x(0, 1, 1, 4)         - AIC:635.39
# The best model for (170, 'Blocks of flats, one-room flat') is: SARIMAX(0, 1, 1)x(0, 1, 1, 4)         - AIC:609.86
# The best model for (160, 'Building types total') is: SARIMAX(2, 1, 2)x(0, 1, 1, 4)         - AIC:600.94
# The best model for (170, 'Blocks of flats, three-room flat+') is: SARIMAX(0, 1, 1)x(0, 1, 1, 4)         - AIC:581.22
# The best model for (170, 'Blocks of flats total') is: SARIMAX(0, 1, 1)x(0, 1, 1, 4)         - AIC:552.97
# The best model for (170, 'Building types total') is: SARIMAX(0, 1, 1)x(1, 1, 1, 4)         - AIC:552.58
# The best model for (170, 'Blocks of flats, two-room flat') is: SARIMAX(0, 1, 1)x(1, 1, 1, 4)         - AIC:587.92
# The best model for (180, 'Blocks of flats, one-room flat') is: SARIMAX(1, 1, 1)x(1, 1, 2, 4)         - AIC:12.0
# The best model for (180, 'Blocks of flats total') is: SARIMAX(0, 1, 1)x(0, 1, 1, 4)         - AIC:575.44
# The best model for (180, 'Building types total') is: SARIMAX(1, 1, 1)x(0, 1, 1, 4)         - AIC:581.89
# The best model for (200, 'Blocks of flats, two-room flat') is: SARIMAX(1, 1, 0)x(0, 1, 1, 4)         - AIC:526.31
# The best model for (180, 'Blocks of flats, two-room flat') is: SARIMAX(0, 1, 1)x(0, 1, 1, 4)         - AIC:598.68
# The best model for (180, 'Blocks of flats, three-room flat+') is: SARIMAX(0, 1, 2)x(1, 1, 2, 4)         - AIC:12.0
# The best model for (200, 'Blocks of flats, three-room flat+') is: SARIMAX(2, 1, 0)x(0, 1, 1, 4)         - AIC:547.25
# The best model for (200, 'Building types total') is: SARIMAX(1, 1, 0)x(1, 1, 2, 4)         - AIC:508.07
# {"(100, 'Blocks of flats total')": ((0, 1, 1), (0, 1, 1, 4)),
#  "(100, 'Blocks of flats, one-room flat')": ((0, 1, 1), (0, 1, 1, 4)),
#  "(100, 'Blocks of flats, three-room flat+')": ((1, 1, 0), (0, 1, 1, 4)),
#  "(100, 'Blocks of flats, two-room flat')": ((0, 1, 1), (0, 1, 1, 4)),
#  "(100, 'Building types total')": ((0, 1, 1), (0, 1, 1, 4)),
#  "(120, 'Blocks of flats total')": ((0, 1, 1), (0, 1, 1, 4)),
#  "(120, 'Blocks of flats, one-room flat')": ((0, 1, 1), (0, 1, 1, 4)),
#  "(120, 'Blocks of flats, three-room flat+')": ((0, 1, 1), (0, 1, 1, 4)),
#  "(120, 'Blocks of flats, two-room flat')": ((0, 1, 1), (0, 1, 1, 4)),
#  "(120, 'Building types total')": ((1, 1, 0), (0, 1, 1, 4)),
#  "(130, 'Blocks of flats total')": ((2, 1, 0), (2, 1, 1, 4)),
#  "(130, 'Building types total')": ((2, 1, 0), (2, 1, 1, 4)),
#  "(140, 'Blocks of flats total')": ((0, 1, 1), (0, 1, 1, 4)),
#  "(140, 'Blocks of flats, one-room flat')": ((0, 1, 1), (0, 1, 1, 4)),
#  "(140, 'Blocks of flats, three-room flat+')": ((0, 1, 1), (0, 1, 1, 4)),
#  "(140, 'Blocks of flats, two-room flat')": ((2, 1, 1), (2, 1, 2, 4)),
#  "(140, 'Building types total')": ((1, 1, 1), (0, 1, 1, 4)),
#  "(150, 'Blocks of flats total')": ((1, 1, 0), (0, 1, 1, 4)),
#  "(150, 'Blocks of flats, one-room flat')": ((1, 1, 0), (0, 1, 1, 4)),
#  "(150, 'Blocks of flats, three-room flat+')": ((0, 1, 1), (0, 1, 1, 4)),
#  "(150, 'Blocks of flats, two-room flat')": ((0, 1, 1), (0, 1, 2, 4)),
#  "(150, 'Building types total')": ((1, 1, 0), (0, 1, 1, 4)),
#  "(160, 'Blocks of flats total')": ((0, 1, 2), (0, 1, 1, 4)),
#  "(160, 'Blocks of flats, three-room flat+')": ((2, 1, 1), (0, 1, 1, 4)),
#  "(160, 'Building types total')": ((2, 1, 2), (0, 1, 1, 4)),
#  "(170, 'Blocks of flats total')": ((0, 1, 1), (0, 1, 1, 4)),
#  "(170, 'Blocks of flats, one-room flat')": ((0, 1, 1), (0, 1, 1, 4)),
#  "(170, 'Blocks of flats, three-room flat+')": ((0, 1, 1), (0, 1, 1, 4)),
#  "(170, 'Blocks of flats, two-room flat')": ((0, 1, 1), (1, 1, 1, 4)),
#  "(170, 'Building types total')": ((0, 1, 1), (1, 1, 1, 4)),
#  "(180, 'Blocks of flats total')": ((0, 1, 1), (0, 1, 1, 4)),
#  "(180, 'Blocks of flats, one-room flat')": ((1, 1, 1), (1, 1, 2, 4)),
#  "(180, 'Blocks of flats, three-room flat+')": ((0, 1, 2), (1, 1, 2, 4)),
#  "(180, 'Blocks of flats, two-room flat')": ((0, 1, 1), (0, 1, 1, 4)),
#  "(180, 'Building types total')": ((1, 1, 1), (0, 1, 1, 4)),
#  "(200, 'Blocks of flats, three-room flat+')": ((2, 1, 0), (0, 1, 1, 4)),
#  "(200, 'Blocks of flats, two-room flat')": ((1, 1, 0), (0, 1, 1, 4)),
#  "(200, 'Building types total')": ((1, 1, 0), (1, 1, 2, 4))}

# %%
res_df = pd.DataFrame(res).T
pdq = pd.DataFrame(res_df.iloc[:,0].tolist(), index=res_df.index,columns=['p','d','q'])
PDQs = pd.DataFrame(res_df.iloc[:,1].tolist(), index=res_df.index,columns=['P','D','Q','s'])

res_df = pd.concat([pdq,PDQs], axis=1)
res_df.to_csv('res_df.csv',index=True)
res_df.head()
# Out:
#                                             p  d  q  P  D  Q  s
# (130, 'Building types total')               2  1  0  2  1  1  4
# (130, 'Blocks of flats total')              2  1  0  2  1  1  4
# (100, 'Blocks of flats, three-room flat+')  1  1  0  0  1  1  4
# (120, 'Building types total')               1  1  0  0  1  1  4
# (100, 'Blocks of flats, two-room flat')     0  1  1  0  1  1  4

# %%
res_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 38 entries, (130, 'Building types total') to (200, 'Building types total')
# Data columns (total 7 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   p       38 non-null     int64
#  1   d       38 non-null     int64
#  2   q       38 non-null     int64
#  3   P       38 non-null     int64
#  4   D       38 non-null     int64
#  5   Q       38 non-null     int64
#  6   s       38 non-null     int64
# dtypes: int64(7)
# memory usage: 2.4+ KB

# %%
res_df = pd.read_csv('res_df.csv',index_col=[0])
res_df
# Out:
#                                             p  d  q  P  D  Q  s
# (130, 'Building types total')               2  1  0  2  1  1  4
# (130, 'Blocks of flats total')              2  1  0  2  1  1  4
# (100, 'Blocks of flats, three-room flat+')  1  1  0  0  1  1  4
# (120, 'Building types total')               1  1  0  0  1  1  4
# (100, 'Blocks of flats, two-room flat')     0  1  1  0  1  1  4
# (120, 'Blocks of flats, three-room flat+')  0  1  1  0  1  1  4
# (100, 'Blocks of flats, one-room flat')     0  1  1  0  1  1  4
# (120, 'Blocks of flats, one-room flat')     0  1  1  0  1  1  4
# (120, 'Blocks of flats total')              0  1  1  0  1  1  4
# (120, 'Blocks of flats, two-room flat')     0  1  1  0  1  1  4
# (100, 'Blocks of flats total')              0  1  1  0  1  1  4
# (100, 'Building types total')               0  1  1  0  1  1  4
# (140, 'Blocks of flats total')              0  1  1  0  1  1  4
# (140, 'Blocks of flats, one-room flat')     0  1  1  0  1  1  4
# (150, 'Blocks of flats, two-room flat')     0  1  1  0  1  2  4
# (140, 'Blocks of flats, two-room flat')     2  1  1  2  1  2  4
# (140, 'Blocks of flats, three-room flat+')  0  1  1  0  1  1  4
# (140, 'Building types total')               1  1  1  0  1  1  4
# (150, 'Blocks of flats total')              1  1  0  0  1  1  4
# (150, 'Building types total')               1  1  0  0  1  1  4
# (150, 'Blocks of flats, one-room flat')     1  1  0  0  1  1  4
# (160, 'Blocks of flats, three-room flat+')  2  1  1  0  1  1  4
# (160, 'Blocks of flats total')              0  1  2  0  1  1  4
# (150, 'Blocks of flats, three-room flat+')  0  1  1  0  1  1  4
# (170, 'Blocks of flats, one-room flat')     0  1  1  0  1  1  4
# (160, 'Building types total')               2  1  2  0  1  1  4
# (170, 'Blocks of flats, three-room flat+')  0  1  1  0  1  1  4
# (170, 'Blocks of flats total')              0  1  1  0  1  1  4
# (170, 'Building types total')               0  1  1  1  1  1  4
# (170, 'Blocks of flats, two-room flat')     0  1  1  1  1  1  4
# (180, 'Blocks of flats, one-room flat')     1  1  1  1  1  2  4
# (180, 'Blocks of flats total')              0  1  1  0  1  1  4
# (180, 'Building types total')               1  1  1  0  1  1  4
# (200, 'Blocks of flats, two-room flat')     1  1  0  0  1  1  4
# (180, 'Blocks of flats, two-room flat')     0  1  1  0  1  1  4
# (180, 'Blocks of flats, three-room flat+')  0  1  2  1  1  2  4
# (200, 'Blocks of flats, three-room flat+')  2  1  0  0  1  1  4
# (200, 'Building types total')               1  1  0  1  1  2  4
