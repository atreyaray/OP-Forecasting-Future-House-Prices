# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv('014_112p_2021q2_20210920-161913.csv', encoding="unicode_escape",sep='\t', skiprows=1)
df
# Out:
#                                              Postal code  \
# 0      00100 Helsinki Keskusta - Etu-Töölö   (Helsinki )
# 1      00100 Helsinki Keskusta - Etu-Töölö   (Helsinki )
# 2      00100 Helsinki Keskusta - Etu-Töölö   (Helsinki )
# 3      00100 Helsinki Keskusta - Etu-Töölö   (Helsinki )
# 4      00100 Helsinki Keskusta - Etu-Töölö   (Helsinki )
# ...                                                  ...
# 10069                  99980 Utsjoki Keskus   (Utsjoki )
# 10070                  99980 Utsjoki Keskus   (Utsjoki )
# 10071                  99980 Utsjoki Keskus   (Utsjoki )
# 10072                  99980 Utsjoki Keskus   (Utsjoki )
# 10073                  99980 Utsjoki Keskus   (Utsjoki )
#
#                            Building type  \
# 0         Blocks of flats, one-room flat
# 1         Blocks of flats, two-room flat
# 2      Blocks of flats, three-room flat+
# 3                  Blocks of flats total
# 4                  Terraced houses total
# ...

# %%
df.columns
# Out:
# Index(['Postal code', 'Building type',
#        '2010Q1 Price per square meter (EUR/m2)',
#        '2010Q2 Price per square meter (EUR/m2)',
#        '2010Q3 Price per square meter (EUR/m2)',
#        '2010Q4 Price per square meter (EUR/m2)',
#        '2011Q1 Price per square meter (EUR/m2)',
#        '2011Q2 Price per square meter (EUR/m2)',
#        '2011Q3 Price per square meter (EUR/m2)',
#        '2011Q4 Price per square meter (EUR/m2)',
#        '2012Q1 Price per square meter (EUR/m2)',
#        '2012Q2 Price per square meter (EUR/m2)',
#        '2012Q3 Price per square meter (EUR/m2)',
#        '2012Q4 Price per square meter (EUR/m2)',
#        '2013Q1 Price per square meter (EUR/m2)',
#        '2013Q2 Price per square meter (EUR/m2)',
#        '2013Q3 Price per square meter (EUR/m2)',
#        '2013Q4 Price per square meter (EUR/m2)',
#        '2014Q1 Price per square meter (EUR/m2)',
#        '2014Q2 Price per square meter (EUR/m2)',
# ...

# %%
df['Postal Code'] = df['Postal code'].map(lambda x: x[0:5])
df['Location'] = df['Postal code'].map(lambda x: x[5:])
df.drop(columns = ['Postal code'],inplace=True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~/opt/anaconda3/lib/python3.7/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2645             try:
# -> 2646                 return self._engine.get_loc(key)
#    2647             except KeyError:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Postal code'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-45-8b85f2a853e6> in <module>
# ...

# %%
df.sample(5)
# Out:
#                           Building type  \
# 4023              Blocks of flats total
# 861               Blocks of flats total
# 1099     Blocks of flats, two-room flat
# 4287              Blocks of flats total
# 4928  Blocks of flats, three-room flat+
#
#      2010Q1 Price per square meter (EUR/m2)  \
# 4023                                     ..
# 861                                    2616
# 1099                                     ..
# 4287                                     ..
# 4928                                     ..
#
#      2010Q2 Price per square meter (EUR/m2)  \
# 4023                                     ..
# 861                                    2691
# 1099                                     ..
# 4287                                     ..
# 4928                                     ..
#
#      2010Q3 Price per square meter (EUR/m2)  \
# 4023                                     ..
# 861                                    2588
# ...

# %%
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-51-71633c051be6> in <module>
# ----> 1 df = df.groupby('Postal Code').count()
#
# ~/opt/anaconda3/lib/python3.7/site-packages/pandas/core/groupby/groupby.py in __getattr__(self, attr)
#     579
#     580         raise AttributeError(
# --> 581             f"'{type(self).__name__}' object has no attribute '{attr}'"
#     582         )
#     583
#
# AttributeError: 'DataFrameGroupBy' object has no attribute 'groupby'
