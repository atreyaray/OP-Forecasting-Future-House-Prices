# %% [markdown]
# # CS-C3250 - Data Science Project: Predicting Housing Prices in One Year
# __Sponsored by OP bank__

# %% [markdown]
# ## Exploratory Data Analysis

# %% [markdown]
# Importing necessary libraries.

# %%
import numpy as np
import pandas as pd
from matplotlib import pyplot as plt

# %%
ls
# Out:
# bruce_eda.ipynb  dean_eda.ipynb   ray_eda.ipynb

# %% [markdown]
# Reading the data.

# %%
df = pd.read_csv("../data/quarterly_data.csv", encoding = 'unicode_escape')
df
# Out:
#                                              Postal code  \
# 0      00100 Helsinki Keskusta - Etu-Töölö   (Helsinki )
# 1      00100 Helsinki Keskusta - Etu-Töölö   (Helsinki )
# 2      00100 Helsinki Keskusta - Etu-Töölö   (Helsinki )
# 3      00100 Helsinki Keskusta - Etu-Töölö   (Helsinki )
# 4      00100 Helsinki Keskusta - Etu-Töölö   (Helsinki )
# ...                                                  ...
# 10069                  99980 Utsjoki Keskus   (Utsjoki )
# 10070                  99980 Utsjoki Keskus   (Utsjoki )
# 10071                  99980 Utsjoki Keskus   (Utsjoki )
# 10072                  99980 Utsjoki Keskus   (Utsjoki )
# 10073                  99980 Utsjoki Keskus   (Utsjoki )
#
#                            Building type  \
# 0         Blocks of flats, one-room flat
# 1         Blocks of flats, two-room flat
# 2      Blocks of flats, three-room flat+
# 3                  Blocks of flats total
# 4                  Terraced houses total
# ...                                  ...
# 10069     Blocks of flats, two-room flat
# 10070  Blocks of flats, three-room flat+
# 10071              Blocks of flats total
# 10072              Terraced houses total
# 10073               Building types total
#
#       2010Q1 Price per square meter (EUR/m2)  \
# 0                                       5458
# 1                                       5164
# 2                                       4944
# 3                                       5168
# 4                                         ..
# ...                                      ...
# 10069                                     ..
# 10070                                     ..
# 10071                                     ..
# 10072                                     ..
# 10073                                     ..
#
#       2010Q2 Price per square meter (EUR/m2)  \
# 0                                       5347
# 1                                       5021
# 2                                       5396
# 3                                       5219
# 4                                         ..
# ...                                      ...
# 10069                                     ..
# 10070                                     ..
# 10071                                     ..
# 10072                                     ..
# 10073                                     ..
#
#       2010Q3 Price per square meter (EUR/m2)  \
# 0                                       5826
# 1                                       5081
# 2                                       4828
# 3                                       5181
# 4                                         ..
# ...                                      ...
# 10069                                     ..
# 10070                                     ..
# 10071                                     ..
# 10072                                     ..
# 10073                                     ..
#
#       2010Q4 Price per square meter (EUR/m2)  \
# 0                                       5566
# 1                                       5006
# 2                                       5394
# 3                                       5269
# 4                                         ..
# ...                                      ...
# 10069                                     ..
# 10070                                     ..
# 10071                                     ..
# 10072                                     ..
# 10073                                     ..
#
#       2011Q1 Price per square meter (EUR/m2)  \
# 0                                       5545
# 1                                       5713
# 2                                       5571
# 3                                       5632
# 4                                         ..
# ...                                      ...
# 10069                                     ..
# 10070                                     ..
# 10071                                     ..
# 10072                                     ..
# 10073                                     ..
#
#       2011Q2 Price per square meter (EUR/m2)  \
# 0                                       5812
# 1                                       5866
# 2                                       5709
# 3                                       5807
# 4                                         ..
# ...                                      ...
# 10069                                     ..
# 10070                                     ..
# 10071                                     ..
# 10072                                     ..
# 10073                                     ..
#
#       2011Q3 Price per square meter (EUR/m2)  \
# 0                                       5909
# 1                                       5552
# 2                                       5450
# 3                                       5630
# 4                                         ..
# ...                                      ...
# 10069                                     ..
# 10070                                     ..
# 10071                                     ..
# 10072                                     ..
# 10073                                     ..
#
#       2011Q4 Price per square meter (EUR/m2)  ...  \
# 0                                       5856  ...
# 1                                       5614  ...
# 2                                       5010  ...
# 3                                       5511  ...
# 4                                         ..  ...
# ...                                      ...  ...
# 10069                                     ..  ...
# 10070                                     ..  ...
# 10071                                     ..  ...
# 10072                                     ..  ...
# 10073                                     ..  ...
#
#       2019Q1 Price per square meter (EUR/m2)  \
# 0                                       7755
# 1                                       6914
# 2                                       6883
# 3                                       7043
# 4                                         ..
# ...                                      ...
# 10069                                     ..
# 10070                                     ..
# 10071                                     ..
# 10072                                     ..
# 10073                                     ..
#
#       2019Q2 Price per square meter (EUR/m2)  \
# 0                                       8332
# 1                                       7694
# 2                                       6846
# 3                                       7478
# 4                                         ..
# ...                                      ...
# 10069                                     ..
# 10070                                     ..
# 10071                                     ..
# 10072                                     ..
# 10073                                     ..
#
#       2019Q3 Price per square meter (EUR/m2)  \
# 0                                       8130
# 1                                       6901
# 2                                       7379
# 3                                       7476
# 4                                         ..
# ...                                      ...
# 10069                                     ..
# 10070                                     ..
# 10071                                     ..
# 10072                                     ..
# 10073                                     ..
#
#       2019Q4 Price per square meter (EUR/m2)  \
# 0                                       8068
# 1                                       7435
# 2                                       6728
# 3                                       7345
# 4                                         ..
# ...                                      ...
# 10069                                     ..
# 10070                                     ..
# 10071                                     ..
# 10072                                     ..
# 10073                                     ..
#
#       2020Q1 Price per square meter (EUR/m2)  \
# 0                                       7802
# 1                                       7573
# 2                                       7205
# 3                                       7460
# 4                                         ..
# ...                                      ...
# 10069                                     ..
# 10070                                     ..
# 10071                                     ..
# 10072                                     ..
# 10073                                     ..
#
#       2020Q2 Price per square meter (EUR/m2)  \
# 0                                       8543
# 1                                       7398
# 2                                       6678
# 3                                       7275
# 4                                         ..
# ...                                      ...
# 10069                                     ..
# 10070                                     ..
# 10071                                     ..
# 10072                                     ..
# 10073                                     ..
#
#       2020Q3 Price per square meter (EUR/m2)  \
# 0                                       9170
# 1                                       7868
# 2                                       7178
# 3                                       8058
# 4                                         ..
# ...                                      ...
# 10069                                     ..
# 10070                                     ..
# 10071                                     ..
# 10072                                     ..
# 10073                                     ..
#
#       2020Q4 Price per square meter (EUR/m2)  \
# 0                                       7517
# 1                                       7700
# 2                                       7405
# 3                                       7540
# 4                                         ..
# ...                                      ...
# 10069                                     ..
# 10070                                     ..
# 10071                                     ..
# 10072                                     ..
# 10073                                     ..
#
#       2021Q1* Price per square meter (EUR/m2)  \
# 0                                        8872
# 1                                        7829
# 2                                        8053
# 3                                        8188
# 4                                          ..
# ...                                       ...
# 10069                                      ..
# 10070                                      ..
# 10071                                      ..
# 10072                                      ..
# 10073                                      ..
#
#       2021Q2* Price per square meter (EUR/m2)
# 0                                        8596
# 1                                        7974
# 2                                        8174
# 3                                        8188
# 4                                          ..
# ...                                       ...
# 10069                                      ..
# 10070                                      ..
# 10071                                      ..
# 10072                                      ..
# 10073                                      ..
#
# [10074 rows x 48 columns]

# %% [markdown]
# Transform location description to only postal code

# %%
codes = df.iloc[:,0].apply(lambda x: x[:5])

# %% [markdown]
# Getting indicies and column names

# %%
indices = pd.MultiIndex.from_arrays((codes, df.iloc[:,1]))
columns = df.iloc[:,2:].columns
df1 = pd.DataFrame(df.iloc[:,2:].to_numpy(), index=indices, columns=columns)

# %% [markdown]
# Force cell values to numeric type, in the process turning non-numeric cells ("..") to NaN values.

# %%
df1 = df1.apply(pd.to_numeric, errors="coerce")
df1.head()
# Out:
#                                                2010Q1 Price per square meter (EUR/m2)  \
# Postal code Building type
# 00100       Blocks of flats, one-room flat                                     5458.0
#             Blocks of flats, two-room flat                                     5164.0
#             Blocks of flats, three-room flat+                                  4944.0
#             Blocks of flats total                                              5168.0
#             Terraced houses total                                                 NaN
#
#                                                2010Q2 Price per square meter (EUR/m2)  \
# Postal code Building type
# 00100       Blocks of flats, one-room flat                                     5347.0
#             Blocks of flats, two-room flat                                     5021.0
#             Blocks of flats, three-room flat+                                  5396.0
#             Blocks of flats total                                              5219.0
#             Terraced houses total                                                 NaN
#
#                                                2010Q3 Price per square meter (EUR/m2)  \
# Postal code Building type
# 00100       Blocks of flats, one-room flat                                     5826.0
#             Blocks of flats, two-room flat                                     5081.0
#             Blocks of flats, three-room flat+                                  4828.0
#             Blocks of flats total                                              5181.0
#             Terraced houses total                                                 NaN
#
#                                                2010Q4 Price per square meter (EUR/m2)  \
# Postal code Building type
# 00100       Blocks of flats, one-room flat                                     5566.0
#             Blocks of flats, two-room flat                                     5006.0
#             Blocks of flats, three-room flat+                                  5394.0
#             Blocks of flats total                                              5269.0
#             Terraced houses total                                                 NaN
#
#                                                2011Q1 Price per square meter (EUR/m2)  \
# Postal code Building type
# 00100       Blocks of flats, one-room flat                                     5545.0
#             Blocks of flats, two-room flat                                     5713.0
#             Blocks of flats, three-room flat+                                  5571.0
#             Blocks of flats total                                              5632.0
#             Terraced houses total                                                 NaN
#
#                                                2011Q2 Price per square meter (EUR/m2)  \
# Postal code Building type
# 00100       Blocks of flats, one-room flat                                     5812.0
#             Blocks of flats, two-room flat                                     5866.0
#             Blocks of flats, three-room flat+                                  5709.0
#             Blocks of flats total                                              5807.0
#             Terraced houses total                                                 NaN
#
#                                                2011Q3 Price per square meter (EUR/m2)  \
# Postal code Building type
# 00100       Blocks of flats, one-room flat                                     5909.0
#             Blocks of flats, two-room flat                                     5552.0
#             Blocks of flats, three-room flat+                                  5450.0
#             Blocks of flats total                                              5630.0
#             Terraced houses total                                                 NaN
#
#                                                2011Q4 Price per square meter (EUR/m2)  \
# Postal code Building type
# 00100       Blocks of flats, one-room flat                                     5856.0
#             Blocks of flats, two-room flat                                     5614.0
#             Blocks of flats, three-room flat+                                  5010.0
#             Blocks of flats total                                              5511.0
#             Terraced houses total                                                 NaN
#
#                                                2012Q1 Price per square meter (EUR/m2)  \
# Postal code Building type
# 00100       Blocks of flats, one-room flat                                     5785.0
#             Blocks of flats, two-room flat                                     6020.0
#             Blocks of flats, three-room flat+                                  5704.0
#             Blocks of flats total                                              5843.0
#             Terraced houses total                                                 NaN
#
#                                                2012Q2 Price per square meter (EUR/m2)  \
# Postal code Building type
# 00100       Blocks of flats, one-room flat                                     6436.0
#             Blocks of flats, two-room flat                                     5814.0
#             Blocks of flats, three-room flat+                                  5466.0
#             Blocks of flats total                                              5899.0
#             Terraced houses total                                                 NaN
#
#                                                ...  \
# Postal code Building type                      ...
# 00100       Blocks of flats, one-room flat     ...
#             Blocks of flats, two-room flat     ...
#             Blocks of flats, three-room flat+  ...
#             Blocks of flats total              ...
#             Terraced houses total              ...
#
#                                                2019Q1 Price per square meter (EUR/m2)  \
# Postal code Building type
# 00100       Blocks of flats, one-room flat                                     7755.0
#             Blocks of flats, two-room flat                                     6914.0
#             Blocks of flats, three-room flat+                                  6883.0
#             Blocks of flats total                                              7043.0
#             Terraced houses total                                                 NaN
#
#                                                2019Q2 Price per square meter (EUR/m2)  \
# Postal code Building type
# 00100       Blocks of flats, one-room flat                                     8332.0
#             Blocks of flats, two-room flat                                     7694.0
#             Blocks of flats, three-room flat+                                  6846.0
#             Blocks of flats total                                              7478.0
#             Terraced houses total                                                 NaN
#
#                                                2019Q3 Price per square meter (EUR/m2)  \
# Postal code Building type
# 00100       Blocks of flats, one-room flat                                     8130.0
#             Blocks of flats, two-room flat                                     6901.0
#             Blocks of flats, three-room flat+                                  7379.0
#             Blocks of flats total                                              7476.0
#             Terraced houses total                                                 NaN
#
#                                                2019Q4 Price per square meter (EUR/m2)  \
# Postal code Building type
# 00100       Blocks of flats, one-room flat                                     8068.0
#             Blocks of flats, two-room flat                                     7435.0
#             Blocks of flats, three-room flat+                                  6728.0
#             Blocks of flats total                                              7345.0
#             Terraced houses total                                                 NaN
#
#                                                2020Q1 Price per square meter (EUR/m2)  \
# Postal code Building type
# 00100       Blocks of flats, one-room flat                                     7802.0
#             Blocks of flats, two-room flat                                     7573.0
#             Blocks of flats, three-room flat+                                  7205.0
#             Blocks of flats total                                              7460.0
#             Terraced houses total                                                 NaN
#
#                                                2020Q2 Price per square meter (EUR/m2)  \
# Postal code Building type
# 00100       Blocks of flats, one-room flat                                     8543.0
#             Blocks of flats, two-room flat                                     7398.0
#             Blocks of flats, three-room flat+                                  6678.0
#             Blocks of flats total                                              7275.0
#             Terraced houses total                                                 NaN
#
#                                                2020Q3 Price per square meter (EUR/m2)  \
# Postal code Building type
# 00100       Blocks of flats, one-room flat                                     9170.0
#             Blocks of flats, two-room flat                                     7868.0
#             Blocks of flats, three-room flat+                                  7178.0
#             Blocks of flats total                                              8058.0
#             Terraced houses total                                                 NaN
#
#                                                2020Q4 Price per square meter (EUR/m2)  \
# Postal code Building type
# 00100       Blocks of flats, one-room flat                                     7517.0
#             Blocks of flats, two-room flat                                     7700.0
#             Blocks of flats, three-room flat+                                  7405.0
#             Blocks of flats total                                              7540.0
#             Terraced houses total                                                 NaN
#
#                                                2021Q1* Price per square meter (EUR/m2)  \
# Postal code Building type
# 00100       Blocks of flats, one-room flat                                      8872.0
#             Blocks of flats, two-room flat                                      7829.0
#             Blocks of flats, three-room flat+                                   8053.0
#             Blocks of flats total                                               8188.0
#             Terraced houses total                                                  NaN
#
#                                                2021Q2* Price per square meter (EUR/m2)
# Postal code Building type
# 00100       Blocks of flats, one-room flat                                      8596.0
#             Blocks of flats, two-room flat                                      7974.0
#             Blocks of flats, three-room flat+                                   8174.0
#             Blocks of flats total                                               8188.0
#             Terraced houses total                                                  NaN
#
# [5 rows x 46 columns]

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# MultiIndex: 10074 entries, ('00100', 'Blocks of flats, one-room flat') to ('99980', 'Building types total')
# Data columns (total 46 columns):
#  #   Column                                   Non-Null Count  Dtype
# ---  ------                                   --------------  -----
#  0   2010Q1 Price per square meter (EUR/m2)   1608 non-null   float64
#  1   2010Q2 Price per square meter (EUR/m2)   1703 non-null   float64
#  2   2010Q3 Price per square meter (EUR/m2)   1637 non-null   float64
#  3   2010Q4 Price per square meter (EUR/m2)   1604 non-null   float64
#  4   2011Q1 Price per square meter (EUR/m2)   1645 non-null   float64
#  5   2011Q2 Price per square meter (EUR/m2)   1691 non-null   float64
#  6   2011Q3 Price per square meter (EUR/m2)   1673 non-null   float64
#  7   2011Q4 Price per square meter (EUR/m2)   1398 non-null   float64
#  8   2012Q1 Price per square meter (EUR/m2)   1557 non-null   float64
#  9   2012Q2 Price per square meter (EUR/m2)   1686 non-null   float64
#  10  2012Q3 Price per square meter (EUR/m2)   2095 non-null   float64
#  11  2012Q4 Price per square meter (EUR/m2)   2003 non-null   float64
#  12  2013Q1 Price per square meter (EUR/m2)   1536 non-null   float64
#  13  2013Q2 Price per square meter (EUR/m2)   1530 non-null   float64
#  14  2013Q3 Price per square meter (EUR/m2)   1478 non-null   float64
#  15  2013Q4 Price per square meter (EUR/m2)   1338 non-null   float64
#  16  2014Q1 Price per square meter (EUR/m2)   1391 non-null   float64
#  17  2014Q2 Price per square meter (EUR/m2)   1437 non-null   float64
#  18  2014Q3 Price per square meter (EUR/m2)   1421 non-null   float64
#  19  2014Q4 Price per square meter (EUR/m2)   1314 non-null   float64
#  20  2015Q1 Price per square meter (EUR/m2)   1387 non-null   float64
#  21  2015Q2 Price per square meter (EUR/m2)   1462 non-null   float64
#  22  2015Q3 Price per square meter (EUR/m2)   1495 non-null   float64
#  23  2015Q4 Price per square meter (EUR/m2)   1397 non-null   float64
#  24  2016Q1 Price per square meter (EUR/m2)   1327 non-null   float64
#  25  2016Q2 Price per square meter (EUR/m2)   1523 non-null   float64
#  26  2016Q3 Price per square meter (EUR/m2)   1427 non-null   float64
#  27  2016Q4 Price per square meter (EUR/m2)   1305 non-null   float64
#  28  2017Q1 Price per square meter (EUR/m2)   1434 non-null   float64
#  29  2017Q2 Price per square meter (EUR/m2)   1392 non-null   float64
#  30  2017Q3 Price per square meter (EUR/m2)   1499 non-null   float64
#  31  2017Q4 Price per square meter (EUR/m2)   1335 non-null   float64
#  32  2018Q1 Price per square meter (EUR/m2)   1353 non-null   float64
#  33  2018Q2 Price per square meter (EUR/m2)   1419 non-null   float64
#  34  2018Q3 Price per square meter (EUR/m2)   1363 non-null   float64
#  35  2018Q4 Price per square meter (EUR/m2)   1353 non-null   float64
#  36  2019Q1 Price per square meter (EUR/m2)   1280 non-null   float64
#  37  2019Q2 Price per square meter (EUR/m2)   1355 non-null   float64
#  38  2019Q3 Price per square meter (EUR/m2)   1412 non-null   float64
#  39  2019Q4 Price per square meter (EUR/m2)   1342 non-null   float64
#  40  2020Q1 Price per square meter (EUR/m2)   1380 non-null   float64
#  41  2020Q2 Price per square meter (EUR/m2)   1258 non-null   float64
#  42  2020Q3 Price per square meter (EUR/m2)   1541 non-null   float64
#  43  2020Q4 Price per square meter (EUR/m2)   1597 non-null   float64
#  44  2021Q1* Price per square meter (EUR/m2)  1578 non-null   float64
#  45  2021Q2* Price per square meter (EUR/m2)  1419 non-null   float64
# dtypes: float64(46)
# memory usage: 3.6+ MB

# %% [markdown]
# Transposing the data for other needs.

# %%
dfT = df1.T
dfT.head()
# Out:
# Postal code                                                     00100  \
# Building type                          Blocks of flats, one-room flat
# 2010Q1 Price per square meter (EUR/m2)                         5458.0
# 2010Q2 Price per square meter (EUR/m2)                         5347.0
# 2010Q3 Price per square meter (EUR/m2)                         5826.0
# 2010Q4 Price per square meter (EUR/m2)                         5566.0
# 2011Q1 Price per square meter (EUR/m2)                         5545.0
#
# Postal code                                                            \
# Building type                          Blocks of flats, two-room flat
# 2010Q1 Price per square meter (EUR/m2)                         5164.0
# 2010Q2 Price per square meter (EUR/m2)                         5021.0
# 2010Q3 Price per square meter (EUR/m2)                         5081.0
# 2010Q4 Price per square meter (EUR/m2)                         5006.0
# 2011Q1 Price per square meter (EUR/m2)                         5713.0
#
# Postal code                                                               \
# Building type                          Blocks of flats, three-room flat+
# 2010Q1 Price per square meter (EUR/m2)                            4944.0
# 2010Q2 Price per square meter (EUR/m2)                            5396.0
# 2010Q3 Price per square meter (EUR/m2)                            4828.0
# 2010Q4 Price per square meter (EUR/m2)                            5394.0
# 2011Q1 Price per square meter (EUR/m2)                            5571.0
#
# Postal code                                                   \
# Building type                          Blocks of flats total
# 2010Q1 Price per square meter (EUR/m2)                5168.0
# 2010Q2 Price per square meter (EUR/m2)                5219.0
# 2010Q3 Price per square meter (EUR/m2)                5181.0
# 2010Q4 Price per square meter (EUR/m2)                5269.0
# 2011Q1 Price per square meter (EUR/m2)                5632.0
#
# Postal code                                                   \
# Building type                          Terraced houses total
# 2010Q1 Price per square meter (EUR/m2)                   NaN
# 2010Q2 Price per square meter (EUR/m2)                   NaN
# 2010Q3 Price per square meter (EUR/m2)                   NaN
# 2010Q4 Price per square meter (EUR/m2)                   NaN
# 2011Q1 Price per square meter (EUR/m2)                   NaN
#
# Postal code                                                  \
# Building type                          Building types total
# 2010Q1 Price per square meter (EUR/m2)               5168.0
# 2010Q2 Price per square meter (EUR/m2)               5219.0
# 2010Q3 Price per square meter (EUR/m2)               5181.0
# 2010Q4 Price per square meter (EUR/m2)               5269.0
# 2011Q1 Price per square meter (EUR/m2)               5632.0
#
# Postal code                                                     00120  \
# Building type                          Blocks of flats, one-room flat
# 2010Q1 Price per square meter (EUR/m2)                         5515.0
# 2010Q2 Price per square meter (EUR/m2)                         5646.0
# 2010Q3 Price per square meter (EUR/m2)                         5395.0
# 2010Q4 Price per square meter (EUR/m2)                         5613.0
# 2011Q1 Price per square meter (EUR/m2)                         5905.0
#
# Postal code                                                            \
# Building type                          Blocks of flats, two-room flat
# 2010Q1 Price per square meter (EUR/m2)                         5349.0
# 2010Q2 Price per square meter (EUR/m2)                         5355.0
# 2010Q3 Price per square meter (EUR/m2)                         5534.0
# 2010Q4 Price per square meter (EUR/m2)                         5321.0
# 2011Q1 Price per square meter (EUR/m2)                         5528.0
#
# Postal code                                                               \
# Building type                          Blocks of flats, three-room flat+
# 2010Q1 Price per square meter (EUR/m2)                            6236.0
# 2010Q2 Price per square meter (EUR/m2)                            5713.0
# 2010Q3 Price per square meter (EUR/m2)                            5884.0
# 2010Q4 Price per square meter (EUR/m2)                            5666.0
# 2011Q1 Price per square meter (EUR/m2)                            5691.0
#
# Postal code                                                   ...  \
# Building type                          Blocks of flats total  ...
# 2010Q1 Price per square meter (EUR/m2)                5618.0  ...
# 2010Q2 Price per square meter (EUR/m2)                5495.0  ...
# 2010Q3 Price per square meter (EUR/m2)                5595.0  ...
# 2010Q4 Price per square meter (EUR/m2)                5521.0  ...
# 2011Q1 Price per square meter (EUR/m2)                5689.0  ...
#
# Postal code                                                        99950  \
# Building type                          Blocks of flats, three-room flat+
# 2010Q1 Price per square meter (EUR/m2)                               NaN
# 2010Q2 Price per square meter (EUR/m2)                               NaN
# 2010Q3 Price per square meter (EUR/m2)                               NaN
# 2010Q4 Price per square meter (EUR/m2)                               NaN
# 2011Q1 Price per square meter (EUR/m2)                               NaN
#
# Postal code                                                   \
# Building type                          Blocks of flats total
# 2010Q1 Price per square meter (EUR/m2)                   NaN
# 2010Q2 Price per square meter (EUR/m2)                   NaN
# 2010Q3 Price per square meter (EUR/m2)                   NaN
# 2010Q4 Price per square meter (EUR/m2)                   NaN
# 2011Q1 Price per square meter (EUR/m2)                   NaN
#
# Postal code                                                   \
# Building type                          Terraced houses total
# 2010Q1 Price per square meter (EUR/m2)                   NaN
# 2010Q2 Price per square meter (EUR/m2)                   NaN
# 2010Q3 Price per square meter (EUR/m2)                   NaN
# 2010Q4 Price per square meter (EUR/m2)                   NaN
# 2011Q1 Price per square meter (EUR/m2)                   NaN
#
# Postal code                                                  \
# Building type                          Building types total
# 2010Q1 Price per square meter (EUR/m2)                  NaN
# 2010Q2 Price per square meter (EUR/m2)                  NaN
# 2010Q3 Price per square meter (EUR/m2)                  NaN
# 2010Q4 Price per square meter (EUR/m2)                  NaN
# 2011Q1 Price per square meter (EUR/m2)                  NaN
#
# Postal code                                                     99980  \
# Building type                          Blocks of flats, one-room flat
# 2010Q1 Price per square meter (EUR/m2)                            NaN
# 2010Q2 Price per square meter (EUR/m2)                            NaN
# 2010Q3 Price per square meter (EUR/m2)                            NaN
# 2010Q4 Price per square meter (EUR/m2)                            NaN
# 2011Q1 Price per square meter (EUR/m2)                            NaN
#
# Postal code                                                            \
# Building type                          Blocks of flats, two-room flat
# 2010Q1 Price per square meter (EUR/m2)                            NaN
# 2010Q2 Price per square meter (EUR/m2)                            NaN
# 2010Q3 Price per square meter (EUR/m2)                            NaN
# 2010Q4 Price per square meter (EUR/m2)                            NaN
# 2011Q1 Price per square meter (EUR/m2)                            NaN
#
# Postal code                                                               \
# Building type                          Blocks of flats, three-room flat+
# 2010Q1 Price per square meter (EUR/m2)                               NaN
# 2010Q2 Price per square meter (EUR/m2)                               NaN
# 2010Q3 Price per square meter (EUR/m2)                               NaN
# 2010Q4 Price per square meter (EUR/m2)                               NaN
# 2011Q1 Price per square meter (EUR/m2)                               NaN
#
# Postal code                                                   \
# Building type                          Blocks of flats total
# 2010Q1 Price per square meter (EUR/m2)                   NaN
# 2010Q2 Price per square meter (EUR/m2)                   NaN
# 2010Q3 Price per square meter (EUR/m2)                   NaN
# 2010Q4 Price per square meter (EUR/m2)                   NaN
# 2011Q1 Price per square meter (EUR/m2)                   NaN
#
# Postal code                                                   \
# Building type                          Terraced houses total
# 2010Q1 Price per square meter (EUR/m2)                   NaN
# 2010Q2 Price per square meter (EUR/m2)                   NaN
# 2010Q3 Price per square meter (EUR/m2)                   NaN
# 2010Q4 Price per square meter (EUR/m2)                   NaN
# 2011Q1 Price per square meter (EUR/m2)                   NaN
#
# Postal code
# Building type                          Building types total
# 2010Q1 Price per square meter (EUR/m2)                  NaN
# 2010Q2 Price per square meter (EUR/m2)                  NaN
# 2010Q3 Price per square meter (EUR/m2)                  NaN
# 2010Q4 Price per square meter (EUR/m2)                  NaN
# 2011Q1 Price per square meter (EUR/m2)                  NaN
#
# [5 rows x 10074 columns]

# %% [markdown]
# Example analysis: examine the number of NaNs in 'Terraced houses total' category

# %%
df1.swaplevel().T["Terraced houses total"].iloc[:,:100].info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 46 entries, 2010Q1 Price per square meter (EUR/m2) to 2021Q2* Price per square meter (EUR/m2)
# Data columns (total 100 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   00100   0 non-null      float64
#  1   00120   0 non-null      float64
#  2   00130   0 non-null      float64
#  3   00140   0 non-null      float64
#  4   00150   0 non-null      float64
#  5   00160   0 non-null      float64
#  6   00170   0 non-null      float64
#  7   00180   0 non-null      float64
#  8   00190   0 non-null      float64
#  9   00200   1 non-null      float64
#  10  00210   0 non-null      float64
#  11  00220   0 non-null      float64
#  12  00240   0 non-null      float64
#  13  00250   0 non-null      float64
#  14  00260   0 non-null      float64
#  15  00270   0 non-null      float64
#  16  00280   0 non-null      float64
#  17  00290   0 non-null      float64
#  18  00300   0 non-null      float64
#  19  00310   0 non-null      float64
#  20  00320   0 non-null      float64
#  21  00330   0 non-null      float64
#  22  00340   0 non-null      float64
#  23  00350   3 non-null      float64
#  24  00360   0 non-null      float64
#  25  00370   15 non-null     float64
#  26  00380   0 non-null      float64
#  27  00390   9 non-null      float64
#  28  00400   0 non-null      float64
#  29  00410   3 non-null      float64
#  30  00420   9 non-null      float64
#  31  00430   14 non-null     float64
#  32  00440   0 non-null      float64
#  33  00500   0 non-null      float64
#  34  00510   0 non-null      float64
#  35  00520   0 non-null      float64
#  36  00530   0 non-null      float64
#  37  00540   0 non-null      float64
#  38  00550   0 non-null      float64
#  39  00560   1 non-null      float64
#  40  00570   3 non-null      float64
#  41  00580   0 non-null      float64
#  42  00590   0 non-null      float64
#  43  00600   0 non-null      float64
#  44  00610   0 non-null      float64
#  45  00620   3 non-null      float64
#  46  00630   0 non-null      float64
#  47  00640   19 non-null     float64
#  48  00650   1 non-null      float64
#  49  00660   9 non-null      float64
#  50  00670   35 non-null     float64
#  51  00680   15 non-null     float64
#  52  00690   8 non-null      float64
#  53  00700   19 non-null     float64
#  54  00710   5 non-null      float64
#  55  00720   10 non-null     float64
#  56  00730   46 non-null     float64
#  57  00740   44 non-null     float64
#  58  00750   33 non-null     float64
#  59  00760   12 non-null     float64
#  60  00770   2 non-null      float64
#  61  00780   40 non-null     float64
#  62  00790   4 non-null      float64
#  63  00800   2 non-null      float64
#  64  00810   0 non-null      float64
#  65  00820   0 non-null      float64
#  66  00830   0 non-null      float64
#  67  00840   41 non-null     float64
#  68  00850   0 non-null      float64
#  69  00870   0 non-null      float64
#  70  00890   0 non-null      float64
#  71  00900   0 non-null      float64
#  72  00910   0 non-null      float64
#  73  00920   22 non-null     float64
#  74  00930   6 non-null      float64
#  75  00940   40 non-null     float64
#  76  00950   11 non-null     float64
#  77  00960   15 non-null     float64
#  78  00970   2 non-null      float64
#  79  00980   45 non-null     float64
#  80  00990   0 non-null      float64
#  81  01120   0 non-null      float64
#  82  01150   12 non-null     float64
#  83  01200   32 non-null     float64
#  84  01230   20 non-null     float64
#  85  01260   29 non-null     float64
#  86  01280   46 non-null     float64
#  87  01300   46 non-null     float64
#  88  01340   0 non-null      float64
#  89  01350   42 non-null     float64
#  90  01360   27 non-null     float64
#  91  01370   31 non-null     float64
#  92  01380   10 non-null     float64
#  93  01390   7 non-null      float64
#  94  01400   4 non-null      float64
#  95  01420   0 non-null      float64
#  96  01450   46 non-null     float64
#  97  01480   21 non-null     float64
#  98  01490   4 non-null      float64
#  99  01510   6 non-null      float64
# dtypes: float64(100)
# memory usage: 37.3+ KB

# %% [markdown]
# Plotting!

# %%
dfT["00100"].plot(figsize=(20,8))
# Out:
# <AxesSubplot:>
